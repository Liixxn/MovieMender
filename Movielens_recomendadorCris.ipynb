# %%
import nltk

# %%
from nltk import RegexpTokenizer

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\crisd\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.corpus import stopwords

# %%
import requests
import pandas as pd
import numpy as np
import seaborn as sns
from bs4 import BeautifulSoup
import warnings


try:
    import nltk
except ModuleNotFoundError:
    # !pip install nltk

try:
    import surprise
except ModuleNotFoundError:
    # !pip install scikit-surprise
    import surprise
try:
    import scipy as sp
except ModuleNotFoundError:
    # !pip install scipy
    import scipy as sp

from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import CountVectorizer
from nltk.corpus import stopwords
from nltk import word_tokenize, RegexpTokenizer
from nltk.stem import SnowballStemmer
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
# Import
header = {
    'User-Agent': 'Chrome 108.0.5359.125',
    'Accept-Language': 'es'
}

# %%
class extraccionSinopsisPeliculas():
    def __init__(self):
        self.cargarFicheroSinopsisDataframe()
    
    def obtenerPeliculasSinId(self):
        self.df_links = pd.read_csv('csv/links.csv')
        self.df_links['tmdbId'] = df_links['tmdbId'].fillna(0)
        contador = []
        for i in range(len(df_links['tmdbId'])):
            if df_links["tmdbId"][i]==0:
                contador.append(df_links["movieId"][i])
                
        return contador
    
    
    def scrapingSinopsisPeliculas(self):
        columnaSinopsis = []
        for idPeli in df_links['tmdbId']:
            print(idPeli)
            if idPeli!=0:
                try:
                    url = "https://www.themoviedb.org/movie/"+str(int(idPeli))
                    page = requests.get(url,headers=header)
                    soup = BeautifulSoup (page.content, 'html.parser')
                    sinopsis = soup.find(class_="overview")
                    sinopsis = str(sinopsis.text)
                    columnaSinopsis.append(sinopsis)
                except:
                    columnaSinopsis.append("Sin Informacion")
            else:
                columnaSinopsis.append("Sin Informacion")

    def escribirSinopsisFichero(self):
        with open(r'sinopsis2.txt', "a", encoding="utf-8") as file:
            for i in columnaSinopsis:
                raw = repr(i)
                raw_replace = raw.replace('\\n', "").replace("'","")
                file.write(raw_replace+"|||")


    def cargarFicheroSinopsisDataframe(self):
        self.df_sinopsis = pd.DataFrame(columns=["sinopsis"])
        with  open('sinopsis2.txt', 'r', encoding="utf-8") as file:
            contents = file.read()
            contents = contents.split('|||')
            
        file.close()
        self.df_sinopsis["sinopsis"] =  contents
        self.df_sinopsis = self.df_sinopsis.iloc[:-1 , :]
        return self.df_sinopsis
    
    
    
    

extract = extraccionSinopsisPeliculas()  
df_sinopsisFinal = extract.cargarFicheroSinopsisDataframe()
df_movies = pd.read_csv('csv/movies.csv')
df_moviesSinopsis = pd.concat([df_movies, df_sinopsisFinal], axis=1)

# %%
df_peliculasConSinopsis = df_moviesSinopsis[df_moviesSinopsis["sinopsis"]!="Sin Informacion"]
df_peliculasConSinopsis = df_peliculasConSinopsis.reset_index()

# %%
class procesamientoTexto():
    
    # Funcion que pasa a minusculas y elimina los signos de puntuacion
    def tratamientoBasico(self, df_sinTratar):
        listatokens = []

        for indiceDF, fila in df_sinTratar.iterrows():
            tokenizer = RegexpTokenizer(r'\w+')
            tokens = tokenizer.tokenize(fila["sinopsis"])
            listatokens.append(tokens)

        for i in range(len(listatokens)):
            listatokens[i] = [w.lower() for w in listatokens[i]]
            df_sinTratar["sinopsis"][i] = listatokens[i]

        return df_sinTratar


    # Funcion que aplica las stopwords al datafram que se le pasa
    def quit_stopwords(self, df_conStopwords):
        listaStopwords = []
        stop_words_sp = set(stopwords.words('spanish'))
        try:
            filtered_sentence = []

            for indiceDF, fila in df_conStopwords.iterrows():
                filtered_sentence = [w for w in fila["sinopsis"] if not w in stop_words_sp]
                listaStopwords.append(filtered_sentence)

            for i in range(len(listaStopwords)):
                df_conStopwords["sinopsis"][i] = listaStopwords[i]

        except Exception as e:
            print(e)

        return df_conStopwords


    # Funcion que aplica el stemming al dataframe que se le pasa
    def stemming(self, df_sinStemming):
        listaStemming = []
        lista_stem = []

        # Se establece el idioma
        stemmer = SnowballStemmer('spanish')

        for indiceDF, fila in df_sinStemming.iterrows():
            if indiceDF != 0:
                lista_stem.append(listaStemming)
                listaStemming = []

            for word in range(len(fila["sinopsis"])):
                w = stemmer.stem(fila["sinopsis"][word])
                listaStemming.append(w)

        for i in range(len(lista_stem)):
            df_sinStemming["sinopsis"][i] = lista_stem[i]
        
        
        return df_sinStemming
    
    def prepararSinopsisTfidf(self, df_peliculasConSinopsis):
        listaUnidos = []
        for i in range(len(df_peliculasConSinopsis["sinopsis"])):
            unidos = " ".join(df_peliculasConSinopsis["sinopsis"][i])

            df_peliculasConSinopsis["sinopsis"][i] = str(unidos)
            
        return df_peliculasConSinopsis

procesar = procesamientoTexto()
procesar.tratamientoBasico(df_peliculasConSinopsis)
procesar.quit_stopwords(df_peliculasConSinopsis)
procesar.stemming(df_peliculasConSinopsis)
procesar.prepararSinopsisTfidf(df_peliculasConSinopsis)
df_peliculasConSinopsis.drop('index', inplace=True, axis=1)
# Out:
# <ipython-input-9-0520662388fa>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sinTratar["sinopsis"][i] = listatokens[i]
# <ipython-input-9-0520662388fa>:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_conStopwords["sinopsis"][i] = listaStopwords[i]
# <ipython-input-9-0520662388fa>:57: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sinStemming["sinopsis"][i] = lista_stem[i]
# <ipython-input-9-0520662388fa>:67: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_peliculasConSinopsis["sinopsis"][i] = str(unidos)

# %%
class procesosSinopsis():


    def recommendations(self, titulo_pelicula, n_similares):
        # Se crea la instancia del tfidf
        tfidfvec = TfidfVectorizer()
        # Convierte el conjunto de datos en una matriz de tokens counts
        tfidf_movie = tfidfvec.fit_transform((df_peliculasConSinopsis["sinopsis"]))
        # Se obtiene la similitud del coseno
        cos_sim = cosine_similarity(tfidf_movie, tfidf_movie)
        # Se obtienen los indices de las peliculas
        indices = pd.Series(df_peliculasConSinopsis.index)

        recommended_movies = []
        # Se obtiene la pelicula pasada
        selected_movie = df_peliculasConSinopsis[df_peliculasConSinopsis["title"]==titulo_pelicula]
        # Se obtiene el indice de la pelicula
        selected_movie_index = selected_movie.index[0]
        # Se obtienen los puntuajes de las similitudes entre las peliculas ordenados de mayor a menor
        similarity_scores = pd.Series(cos_sim[selected_movie_index]).sort_values(ascending = False)
        # Se escogen el numero de peliculas especificadas
        numero_peliculas = list(similarity_scores.iloc[1:n_similares+1].index)
        print("Tu top", str(n_similares) + " de peliculas parecidas a " + titulo_pelicula +":")
        print("")
        contador = 1
        for i in numero_peliculas:
            # Se aniaden a la lista de peliculas recomendadas
            recommended_movies.append(list(df_peliculasConSinopsis.index)[i])
            print(str(contador)+ " - " + df_peliculasConSinopsis.loc[i]["title"])
            contador +=1
        #return recommended_movies

        

    def predecirRatingUsuarioSinopsis(self, user_id, titulo_pelicula):
        
        df_ratingsUsuarios = pd.read_csv('csv/ratings.csv')
    
        if len(df_ratingsUsuarios[df_ratingsUsuarios["userId"]==user_id])!=0:
            selected_user = df_ratingsUsuarios[df_ratingsUsuarios["userId"]==user_id]
            if len(df_peliculasConSinopsis[df_peliculasConSinopsis["title"]==titulo_pelicula])!=0:
                selected_movie = df_peliculasConSinopsis[df_peliculasConSinopsis["title"]==titulo_pelicula]
                selected_movieid = selected_movie["movieId"].values

                if len(selected_user[selected_user["movieId"]==selected_movieid[0]])!=0:
                    df_ratingUsuario = selected_user[selected_user["movieId"]==selected_movieid[0]]
                    ratingPelicula = df_ratingUsuario["rating"].values
                    print("El rating del usuario " + str(user_id) + " para la pelicula " + titulo_pelicula + " es de: " + str(ratingPelicula[0]))
                else:
                    df_userRatings_movies = pd.merge(selected_user, df_peliculasConSinopsis, on="movieId")
                    df_userRatings_movies = df_userRatings_movies.append(selected_movie, ignore_index=True)
                    # Se crea la instancia del tfidf
                    tfidfvec = TfidfVectorizer()
                    # Convierte el conjunto de datos en una matriz de tokens counts
                    tfidf_movie = tfidfvec.fit_transform((df_userRatings_movies["sinopsis"]))
                    # Se obtiene la similitud del coseno
                    cos_sim = cosine_similarity(tfidf_movie, tfidf_movie)


                    recommended_movies = []
                    selected_movie = df_userRatings_movies[df_userRatings_movies["title"]==titulo_pelicula]

                    # Se obtienen los puntuajes de las similitudes entre las peliculas ordenados de mayor a menor
                    similarity_scores = pd.Series(cos_sim[selected_movie_index]).sort_values(ascending = False)

                    # Se obtienen los indices de las peliculas que se parecen, y que no tienen un 0 de similitud
                    indices = []
                    for i in similarity_scores.index:
                        if similarity_scores.loc[i] != 0:
                            indices.append(i)

                    # Se obtienen las peliculas con tal indice
                    df_calculateRating = df_userRatings_movies.iloc[indices[1:]]
                    # Se calcula la media de todas ellas
                    prediction = format(df_calculateRating['rating'].mean(), '.3f')
                    print("")
                    print("El rating del usuario " + str(user_id) + " para la pelicula " + titulo_pelicula + " es de: " + str(prediction))
            else:
                print("La pelicula que desea predecir no contiene una sinopsis en que basarse")
        else:
            print("El usuario no existe")


        
proceso = procesosSinopsis()
proceso.recommendations("Wonder Woman (2009)", 5)
proceso.predecirRatingUsuarioSinopsis(1, "Jumanji (1995)")
# Out:
# Tu top 5 de peliculas parecidas a Wonder Woman (2009):
#
# 1 - Wonder Woman (2017)
# 2 - Justice League (2017)
# 3 - LEGO DC Super Hero Girls: Brain Drain (2017)
# 4 - DC Super Hero Girls: Hero of the Year (2016)
# 5 - Legend (1985)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-7f17b7dc035c> in <module>
#      85 proceso = procesosSinopsis()
#      86 proceso.recommendations("Wonder Woman (2009)", 5)
# ---> 87 proceso.predecirRatingUsuarioSinopsis(1, "Jumanji (1995)")
#
# <ipython-input-10-7f17b7dc035c> in predecirRatingUsuarioSinopsis(self, user_id, titulo_pelicula)
#      62
#      63                     # Se obtienen los puntuajes de las similitudes entre las peliculas ordenados de mayor a menor
# ---> 64                     similarity_scores = pd.Series(cos_sim[selected_movie_index]).sort_values(ascending = False)
#      65
#      66                     # Se obtienen los indices de las peliculas que se parecen, y que no tienen un 0 de similitud
#
# NameError: name 'selected_movie_index' is not defined

# %%
class Procesos:
    def __init__(self):
        self.cargaDocumentos()
    def cargaDocumentos(self):
        self.df_links = pd.read_csv('csv/links.csv')
        self.df_links = self.df_links.dropna()
        self.df_movies = pd.read_csv('csv/movies.csv')
        self.df_movies = self.df_movies.dropna()
        self.df_ratings = pd.read_csv('csv/ratings.csv')
        self.df_ratings = self.df_ratings.dropna()
        self.df_tags = pd.read_csv('csv/tags.csv')
        self.df_tags = self.df_tags.dropna()
        self.df_movies_ratings = self.df_ratings.merge(self.df_movies)[['userId','movieId','title', 'rating','genres']]
        
        self.df_movies_ratings_tags = pd.merge(self.df_movies_ratings, self.df_tags, how='outer')[['userId','movieId','title', 'rating','genres', 'tag']]
        self.df_movies_ratings_tags["tag"] = self.df_movies_ratings_tags["tag"].str.lower()
        #self.df_movies_ratings_tags.fillna("vacio", inplace = True)
        
        self.ratings_table = self.df_movies_ratings.pivot_table(index='userId', columns='title', values='rating')
        #para cambiar los NAN por 0:
        self.ratings_table.fillna(0, inplace=True)
    def recomedacionPorValoracionOtrosUsuarios(self, nombrePelicula, n_similares):
        sparse_rating = sp.sparse.csr_matrix(self.ratings_table)
        similitud_usuarios = cosine_similarity(sparse_rating)
        #se hace con la transpuesta de la matriz creada anteriormente
        similitud_movies = cosine_similarity(sparse_rating.T)
        df_similitud_usuarios = pd.DataFrame(similitud_usuarios, index=self.ratings_table.index, columns=self.ratings_table.index)
        df_similitud_movies = pd.DataFrame(similitud_movies, index=self.ratings_table.columns, columns=self.ratings_table.columns)
        #le sumamos uno a n_similares porque la primera siempre es la propia pelicula y nos la saltamos
        n_similares+=1
        contador = 1
        print('Peliculas similares a ' + nombrePelicula + ':')
        print()
        for movie in df_similitud_movies[nombrePelicula].sort_values(ascending=False).index[1:n_similares]:
            print(str(contador) + ' - ' + str(movie))
            contador+=1
    def recomedacionPorGenero(self, nombrePelicula, n_similares):
        genres = list(set([genre for genres in self.df_movies["genres"].str.split("|") for genre in genres]))
        genre_matrix = []
        for index, row in self.df_movies.iterrows():
            genre_list = row["genres"].split("|")
            genre_vector = [1 if genre in genre_list else 0 for genre in genres]
            genre_matrix.append(genre_vector)
        genre_matrix = pd.DataFrame(genre_matrix, columns=genres)
        contador = 1
        selected_movie = self.df_movies[self.df_movies["title"] == nombrePelicula]
        selected_movie_index = selected_movie.index[0]
        #sacamos las similitudes de los generos
        similarities = cosine_similarity(genre_matrix[selected_movie_index:selected_movie_index+1], genre_matrix).flatten()
        #las metemos en una tupla y las ordenamos de mayor a menor 
        movie_list = [(index, similarity) for index, similarity in enumerate(similarities)]
        movie_list.sort(key=lambda x: x[1], reverse=True)

        print('Peliculas similares a ' + nombrePelicula + ':')
        print()
        #la bandera nos sirve para saltarnos la propia peli que buscamos
        #siempre esta a false y si nos encontramos la peli que estamos buscando la activamos a True
        #si esta en True al finalizar el bucle significa que ha saltado el titulo que buscabamos para no repetirse a si mismo 
        #y por lo tanto hay que añadir uno mas para llegar al numero deseado por el usuario
        bandera=False
        for movie in movie_list[0:n_similares]:
            if(nombrePelicula != self.df_movies.iloc[movie[0]]["title"]):
                print(str(contador)+' - ' +self.df_movies.iloc[movie[0]]["title"])
                contador+=1
            else:
                bandera=True
        if(bandera):
            #print('bandera')
            mov=movie_list[n_similares][0]
            print(str(contador)+' - ' +self.df_movies.iloc[mov]["title"])
    def predecirRatingDeUserAPeliculaPorSusGeneros(self, nombrePelicula, user_id):
        yaVotado = self.df_movies_ratings[(self.df_movies_ratings['title']==nombrePelicula) & (self.df_movies_ratings['userId']==user_id)]["rating"].unique()
        if(len(yaVotado)!=0):
            prediction = yaVotado[0]
            #print()
            print("La prediccion para " + nombrePelicula+" es: " + str(prediction))
            #return prediction
        else:
            # obtener géneros de la película a predecir
            movie_genres = self.df_movies_ratings[self.df_movies_ratings['title']==nombrePelicula]["genres"].unique()
            generosPeli = movie_genres[0].split("|")
            # filtrar valoraciones del usuario para peliculas con generos en comun
            user_ratings_ID = self.df_movies_ratings[self.df_movies_ratings['userId'] == user_id]
            user_ratings = user_ratings_ID.loc[user_ratings_ID['genres'].str.split('|').apply(lambda x: any(i in x for i in generosPeli))]
            # calcular la media de valoraciones del usuario para las peliculas con generos en comun
            if user_ratings.empty:
                print("La lista es empty")
                #return None
            else:
                #prediction = user_ratings_ID['rating'].mean()
                prediction = format(user_ratings['rating'].mean(), '.3f')
                #print()
                print("La prediccion para " + nombrePelicula + " es: " + str(prediction))
                #return prediction
    def recomedacionPorTags(self, nombrePelicula, n_similares):
        count_matrix = self.df_movies_ratings_tags.pivot_table(index='movieId', columns='tag', values='userId')
        #count_matrix = self.df_movies_ratings_tags.pivot_table(index='movieId', columns='tag', values='rating')
        count_matrix.fillna(0, inplace=True)
        sparse_rating = sp.sparse.csr_matrix(count_matrix)
        #print(sparse_rating)    
        selected_movie = self.df_movies[self.df_movies["title"] == nombrePelicula]["movieId"].values[0]
        #print(selected_movie)

        #encontramos el id de la pelicula en la matriz
        selected_movie_index = count_matrix.index.get_loc(selected_movie)

        similarities = cosine_similarity(sparse_rating, sparse_rating[selected_movie_index])

        movie_list = [(index, similarity) for index, similarity in enumerate(similarities)]
        movie_list.sort(key=lambda x: x[1], reverse=True)
        
        print('Peliculas similares a ' + nombrePelicula + ':')
        print()
        bandera=False
        contador = 1
        for movie in movie_list[0:n_similares]:
            if(nombrePelicula != self.df_movies.iloc[movie[0]]["title"]):
                print(str(contador)+' - ' +self.df_movies.iloc[movie[0]]["title"])
                contador+=1
            else:
                bandera=True
        if(bandera):
            mov=movie_list[n_similares][0]
            print(str(contador)+' - ' +self.df_movies.iloc[mov]["title"])
            
    def predecirRatingDeUserAPeliculaPorSusTags(self, nombrePelicula, user_id):
        yaVotado = self.df_movies_ratings[(self.df_movies_ratings['title']==nombrePelicula) & (self.df_movies_ratings['userId']==user_id)]["rating"].unique()
        if(len(yaVotado)!=0):
            prediction = yaVotado[0]
            #print()
            print("La prediccion para " + nombrePelicula+" es: " + str(prediction))
            return prediction
        else:
            # obtener tags de la película a predecir
            tagsPeli = []
            movie_tags = self.df_movies_ratings_tags[self.df_movies_ratings_tags['title']==nombrePelicula]["tag"].unique()
            for m in movie_tags:
                tagsPeli.append(m)
            #print(tagsPeli)
            filtroMergeandoTags = self.df_movies_ratings_tags[['userId','movieId','title', 'rating', 'tag']]
            filtroEnBaseUserId = filtroMergeandoTags[filtroMergeandoTags['userId']==user_id]
            
            #similitud = [distance.cosine(tagsPeli, j['tag']) for i,j in filtroEnBaseUserId.iterrows()]
            
            user_ratings = filtroEnBaseUserId[filtroEnBaseUserId['tag'].isin(tagsPeli)]
            #si el usuario a creado un tag de alguna peli que sea igual a alguno de el de la pelicula buscada filtramos mas el df quitando los nulos
            #si no a hecho ningun tag y todos sus tag son nan dejamos el df como esta ya que si hacemos dropna eliminamos el df entero
            if user_ratings.dropna().size != 0:
                user_ratings = user_ratings.dropna()
            user_ratings
            # calcular la media de valoraciones del usuario para las peliculas con generos en comun
            if user_ratings.empty:
                print("La lista es empty")
                return None
            else:
                #prediction = user_ratings_ID['rating'].mean()
                prediction = format(user_ratings['rating'].mean(), '.3f')
                #print()
                print("La prediccion para " + nombrePelicula + " es: " + str(prediction))
                return prediction

    def recomendacionEnBaseGeneroPelisQueNoHaVistoUsuario(self, user_id, n_similares):
        #warnings.filterwarnings('ignore')
        df_movies_rating_user = self.df_movies_ratings[self.df_movies_ratings['userId']==user_id]
        df_movies_rating_user = df_movies_rating_user.sort_values(by='rating',ascending=False)

        #cogemos los primeros 10 para ver que generos le gustan mas, anteriormente hemos ordenado por genero
        genero_mejor_rating_unicos = list(set([genre for genres in df_movies_rating_user.head(10)["genres"].str.split("|") for genre in genres]))

        # creamos un diccionario para guardar los generos y cuantas veces se repiten
        genre_count = {}
        for g in genero_mejor_rating_unicos:
            genre_count[g] = df_movies_rating_user.head(10)['genres'].str.count(g).sum()

        #ordenamos el diccionario de mayor a menor
        genero_mejor_rating = dict(sorted(genre_count.items(), key=lambda x: x[1], reverse=True))

        #sacamos las pelis que el usuario no ha visto
        df_movies_no_rating_user = self.df_movies[self.df_movies['movieId'].isin(df_movies_rating_user['movieId']) == False]
        #creamos en el df una columna por cada genero que le gusta al usuario y le agregamos cuanto le gusta
        for genre, weight in genero_mejor_rating.items():
            df_movies_no_rating_user[genre] = df_movies_no_rating_user["genres"].str.contains(genre).apply(lambda x: weight if x else 0)
        #creamos una nueva columna con la suma de cada fila para saber que peliculas le pueden gustar mas
        df_movies_no_rating_user["sumaPesos"] = df_movies_no_rating_user[genero_mejor_rating.keys()].sum(axis=1)
        #ordenamos por las pelis que tengan una mayor puntuacion en la columna sumaPesos ya que esto quiere decir que hay muchos generos que le gustan al usuario
        df_movies_no_rating_user = df_movies_no_rating_user.sort_values(by='sumaPesos',ascending=False)

        df_peliculas_mostrar = df_movies_no_rating_user['title'][0:n_similares]

        contador = 1
        for movie in df_peliculas_mostrar:
            print(str(contador)+' - ' +movie)
            contador+=1

        

            

p = Procesos()

#Extra
p.recomedacionPorValoracionOtrosUsuarios("Star Wars: Episode IV - A New Hope (1977)", 10)

print()
#Recomendaciones en base a caracteristicas sueltas
p.recomedacionPorGenero("Star Wars: Episode IV - A New Hope (1977)", 10)
print()
p.recomedacionPorTags("Star Wars: Episode IV - A New Hope (1977)", 10)
print()

#Prediccion de rating mediante un usuario dado
p.predecirRatingDeUserAPeliculaPorSusGeneros("Star Wars: Episode IV - A New Hope (1977)", 1)
print()
p.predecirRatingDeUserAPeliculaPorSusTags("City of God (Cidade de Deus) (2002)", 1)
print()

#Recomendacion en base a un usuario y caracteristicas
p.recomendacionEnBaseGeneroPelisQueNoHaVistoUsuario(1, 10)
# Out:
# Peliculas similares a Star Wars: Episode IV - A New Hope (1977):
#
# 1 - Star Wars: Episode V - The Empire Strikes Back (1980)
# 2 - Star Wars: Episode VI - Return of the Jedi (1983)
# 3 - Raiders of the Lost Ark (Indiana Jones and the Raiders of the Lost Ark) (1981)
# 4 - Matrix, The (1999)
# 5 - Indiana Jones and the Last Crusade (1989)
# 6 - Back to the Future (1985)
# 7 - Star Wars: Episode I - The Phantom Menace (1999)
# 8 - Terminator, The (1984)
# 9 - Godfather, The (1972)
# 10 - Saving Private Ryan (1998)
#
# Peliculas similares a Star Wars: Episode IV - A New Hope (1977):
#
# 1 - Waterworld (1995)
# 2 - Stargate (1994)
# 3 - Demolition Man (1993)
# 4 - Star Wars: Episode V - The Empire Strikes Back (1980)
# 5 - Star Wars: Episode VI - Return of the Jedi (1983)
# 6 - Star Trek III: The Search for Spock (1984)
# 7 - Lost in Space (1998)
# 8 - Rocketeer, The (1991)
# 9 - Tron (1982)
# 10 - Six-String Samurai (1998)
#
# Peliculas similares a Star Wars: Episode IV - A New Hope (1977):
#
# 1 - Misérables, Les (1995)
# 2 - Double Happiness (1994)
# 3 - Replacement Killers, The (1998)
# 4 - Tales from the Hood (1995)
# 5 - Remains of the Day, The (1993)
# 6 - Eddie (1996)
# 7 - Flintstones, The (1994)
# 8 - Airheads (1994)
# 9 - Escape from New York (1981)
# 10 - Tommy Boy (1995)
#
# La prediccion para Star Wars: Episode IV - A New Hope (1977) es: 5.0
#
# La prediccion para City of God (Cidade de Deus) (2002) es: 4.366
#
# 1 - White Sun of the Desert, The (Beloe solntse pustyni) (1970)
# 2 - Dragonheart 2: A New Beginning (2000)
# 3 - Stunt Man, The (1980)
# 4 - Blood Diamond (2006)
# 5 - Little Big Soldier (Da bing xiao jiang) (2010)
# 6 - Hunting Party, The (2007)
# 7 - Aelita: The Queen of Mars (Aelita) (1924)
# 8 - Three Kings (1999)
# 9 - Mulan (1998)
# 10 - Rubber (2010)
# <ipython-input-51-aa4ec8b8b70d>:182: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_movies_no_rating_user[genre] = df_movies_no_rating_user["genres"].str.contains(genre).apply(lambda x: weight if x else 0)
# <ipython-input-51-aa4ec8b8b70d>:184: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_movies_no_rating_user["sumaPesos"] = df_movies_no_rating_user[genero_mejor_rating.keys()].sum(axis=1)

# %%
user_id = 62
df_movies_rating_user = p.df_movies_ratings[p.df_movies_ratings['userId']==user_id]

# %%
df_movies_rating_user
# Out:
#        userId  movieId                                      title  rating  \
# 278        62        6                                Heat (1995)     4.5
# 390        62       47                Seven (a.k.a. Se7en) (1995)     4.5
# 878        62      110                          Braveheart (1995)     4.5
# 1590       62      260  Star Wars: Episode IV - A New Hope (1977)     4.5
# 1851       62      296                        Pulp Fiction (1994)     4.5
# ...       ...      ...                                        ...     ...
# 81526      62   182715                        Annihilation (2018)     4.0
# 81529      62   183611                          Game Night (2018)     4.0
# 81530      62   184471                         Tomb Raider (2018)     3.5
# 81534      62   185031                               Alpha (2018)     4.5
# 81535      62   187595             Solo: A Star Wars Story (2018)     4.0
#
#                                   genres
# 278                Action|Crime|Thriller
# 390                     Mystery|Thriller
# 878                     Action|Drama|War
# 1590             Action|Adventure|Sci-Fi
# 1851         Comedy|Crime|Drama|Thriller
# ...                                  ...
# 81526  Adventure|Mystery|Sci-Fi|Thriller
# 81529         Action|Comedy|Crime|Horror
# 81530           Action|Adventure|Fantasy
# 81534                 Adventure|Thriller
# 81535   Action|Adventure|Children|Sci-Fi
#
# [366 rows x 5 columns]

# %%
p.df_movies[~p.df_movies.movieId.isin(df_movies_rating_user["movieId"])]
# Out:
#       movieId                                      title  \
# 0           1                           Toy Story (1995)
# 2           3                    Grumpier Old Men (1995)
# 3           4                   Waiting to Exhale (1995)
# 4           5         Father of the Bride Part II (1995)
# 6           7                             Sabrina (1995)
# ...       ...                                        ...
# 9737   193581  Black Butler: Book of the Atlantic (2017)
# 9738   193583               No Game No Life: Zero (2017)
# 9739   193585                               Flint (2017)
# 9740   193587        Bungo Stray Dogs: Dead Apple (2018)
# 9741   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                            genres
# 0     Adventure|Animation|Children|Comedy|Fantasy
# 2                                  Comedy|Romance
# 3                            Comedy|Drama|Romance
# 4                                          Comedy
# 6                                  Comedy|Romance
# ...                                           ...
# 9737              Action|Animation|Comedy|Fantasy
# 9738                     Animation|Comedy|Fantasy
# 9739                                        Drama
# 9740                             Action|Animation
# 9741                                       Comedy
#
# [9376 rows x 3 columns]

# %%
df = pd.DataFrame()
movies = p.df_movies[~p.df_movies.movieId.isin(df_movies_rating_user["movieId"])]
df["movieId"] = movies["movieId"]
df["title"] = movies["title"]

# %%
df["ratingPredict"] = [p.predecirRatingDeUserAPeliculaPorSusTags(j["title"], user_id) for i,j in df.iterrows()]
# Out:
# La prediccion para Toy Story (1995) es: 3.000
# La prediccion para Grumpier Old Men (1995) es: 4.131
# La prediccion para Waiting to Exhale (1995) es: 4.131
# La prediccion para Father of the Bride Part II (1995) es: 4.131
# La prediccion para Sabrina (1995) es: 4.131
# La prediccion para Tom and Huck (1995) es: 4.131
# La prediccion para Sudden Death (1995) es: 4.131
# La prediccion para GoldenEye (1995) es: 4.131
# La prediccion para American President, The (1995) es: 3.500
# La prediccion para Dracula: Dead and Loving It (1995) es: 4.131
# La prediccion para Balto (1995) es: 4.131
# La prediccion para Nixon (1995) es: 3.500
# La prediccion para Cutthroat Island (1995) es: 4.131
# La prediccion para Casino (1995) es: 5.000
# La prediccion para Sense and Sensibility (1995) es: 4.131
# La prediccion para Four Rooms (1995) es: 4.131
# La prediccion para Ace Ventura: When Nature Calls (1995) es: 4.131
# La prediccion para Money Train (1995) es: 4.131
# La prediccion para Get Shorty (1995) es: 4.131
# La prediccion para Copycat (1995) es: 4.131
# La prediccion para Assassins (1995) es: 4.131
# La prediccion para Powder (1995) es: 4.131
# La prediccion para Leaving Las Vegas (1995) es: 4.131
# La prediccion para Othello (1995) es: 4.131
# La prediccion para Now and Then (1995) es: 4.131
# La prediccion para Persuasion (1995) es: 4.131
# La prediccion para City of Lost Children, The (Cité des enfants perdus, La) (1995) es: 4.131
# La prediccion para Shanghai Triad (Yao a yao yao dao waipo qiao) (1995) es: 4.131
# La prediccion para Dangerous Minds (1995) es: 4.131
# La prediccion para Twelve Monkeys (a.k.a. 12 Monkeys) (1995) es: 3.250
# La prediccion para Babe (1995) es: 4.131
# La prediccion para Dead Man Walking (1995) es: 4.131
# La prediccion para It Takes Two (1995) es: 4.131
# La prediccion para Clueless (1995) es: 3.409
# La prediccion para Cry, the Beloved Country (1995) es: 4.131
# La prediccion para Richard III (1995) es: 4.131
# La prediccion para Dead Presidents (1995) es: 4.131
# La prediccion para Restoration (1995) es: 4.131
# La prediccion para Mortal Kombat (1995) es: 4.131
# La prediccion para To Die For (1995) es: 4.131
# La prediccion para How to Make an American Quilt (1995) es: 4.131
# La prediccion para Pocahontas (1995) es: 4.131
# La prediccion para When Night Is Falling (1995) es: 4.131
# La prediccion para Usual Suspects, The (1995) es: 3.500
# La prediccion para Mighty Aphrodite (1995) es: 4.131
# La prediccion para Lamerica (1994) es: 4.131
# La prediccion para Big Green, The (1995) es: 4.131
# La prediccion para Georgia (1995) es: 4.131
# La prediccion para Home for the Holidays (1995) es: 4.131
# La prediccion para Postman, The (Postino, Il) (1994) es: 4.131
# La prediccion para Indian in the Cupboard, The (1995) es: 4.131
# La prediccion para Eye for an Eye (1996) es: 4.131
# La prediccion para Mr. Holland's Opus (1995) es: 4.131
# La prediccion para Don't Be a Menace to South Central While Drinking Your Juice in the Hood (1996) es: 4.131
# La prediccion para Two if by Sea (1996) es: 4.131
# La prediccion para Bio-Dome (1996) es: 4.131
# La prediccion para Lawnmower Man 2: Beyond Cyberspace (1996) es: 4.131
# La prediccion para French Twist (Gazon maudit) (1995) es: 4.131
# La prediccion para Friday (1995) es: 4.131
# La prediccion para From Dusk Till Dawn (1996) es: 4.131
# La prediccion para Fair Game (1995) es: 4.131
# La prediccion para Kicking and Screaming (1995) es: 4.131
# La prediccion para Misérables, Les (1995) es: 4.131
# La prediccion para Bed of Roses (1996) es: 4.131
# La prediccion para Big Bully (1996) es: 4.131
# La prediccion para Screamers (1995) es: 4.131
# La prediccion para Nico Icon (1995) es: 4.131
# La prediccion para Crossing Guard, The (1995) es: 4.131
# La prediccion para Juror, The (1996) es: 4.131
# La prediccion para White Balloon, The (Badkonake sefid) (1995) es: 4.131
# La prediccion para Things to Do in Denver When You're Dead (1995) es: 4.131
# La prediccion para Antonia's Line (Antonia) (1995) es: 4.131
# La prediccion para Once Upon a Time... When We Were Colored (1995) es: 4.131
# La prediccion para Angels and Insects (1995) es: 4.131
# La prediccion para White Squall (1996) es: 4.131
# La prediccion para Dunston Checks In (1996) es: 4.131
# La prediccion para Black Sheep (1996) es: 4.131
# La prediccion para Nick of Time (1995) es: 4.131
# La prediccion para Mary Reilly (1996) es: 4.131
# La prediccion para Vampire in Brooklyn (1995) es: 4.131
# La prediccion para Beautiful Girls (1996) es: 4.131
# La prediccion para Broken Arrow (1996) es: 4.131
# La lista es empty
# La prediccion para Hate (Haine, La) (1995) es: 4.131
# La prediccion para Heidi Fleiss: Hollywood Madam (1995) es: 4.131
# La prediccion para City Hall (1996) es: 4.131
# La prediccion para Bottle Rocket (1996) es: 4.500
# La prediccion para Mr. Wrong (1996) es: 4.131
# La prediccion para Unforgettable (1996) es: 4.131
# La prediccion para Happy Gilmore (1996) es: 4.000
# La prediccion para Bridges of Madison County, The (1995) es: 4.131
# La prediccion para Nobody Loves Me (Keiner liebt mich) (1994) es: 4.131
# La prediccion para Muppet Treasure Island (1996) es: 4.131
# La prediccion para Catwalk (1996) es: 4.131
# La prediccion para Taxi Driver (1976) es: 4.131
# La prediccion para Rumble in the Bronx (Hont faan kui) (1995) es: 4.131
# La prediccion para Before and After (1996) es: 4.131
# La prediccion para Anne Frank Remembered (1995) es: 4.131
# La prediccion para Young Poisoner's Handbook, The (1995) es: 4.131
# La prediccion para If Lucy Fell (1996) es: 4.131
# La prediccion para Steal Big, Steal Little (1995) es: 4.131
# La prediccion para Boys of St. Vincent, The (1992) es: 4.131
# La prediccion para Boomerang (1992) es: 4.131
# La prediccion para Chungking Express (Chung Hing sam lam) (1994) es: 4.131
# La prediccion para Flirting With Disaster (1996) es: 4.131
# La prediccion para NeverEnding Story III, The (1994) es: 4.131
# La prediccion para Jupiter's Wife (1994) es: 4.131
# La prediccion para Pie in the Sky (1996) es: 4.131
# La prediccion para Jade (1995) es: 4.131
# La prediccion para Down Periscope (1996) es: 4.131
# La prediccion para Man of the Year (1995) es: 4.131
# La prediccion para Up Close and Personal (1996) es: 4.131
# La prediccion para Birdcage, The (1996) es: 4.131
# La prediccion para Brothers McMullen, The (1995) es: 4.131
# La prediccion para Bad Boys (1995) es: 4.131
# La prediccion para Amazing Panda Adventure, The (1995) es: 4.131
# La prediccion para Basketball Diaries, The (1995) es: 4.750
# La prediccion para Awfully Big Adventure, An (1995) es: 4.131
# La prediccion para Amateur (1994) es: 4.131
# La prediccion para Apollo 13 (1995) es: 3.500
# La prediccion para Rob Roy (1995) es: 4.131
# La prediccion para Addiction, The (1995) es: 4.131
# La prediccion para Batman Forever (1995) es: 3.583
# La prediccion para Beauty of the Day (Belle de jour) (1967) es: 4.131
# La prediccion para Beyond Rangoon (1995) es: 4.131
# La prediccion para Blue in the Face (1995) es: 4.131
# La prediccion para Canadian Bacon (1995) es: 4.131
# La prediccion para Casper (1995) es: 4.131
# La prediccion para Clockers (1995) es: 4.131
# La prediccion para Congo (1995) es: 4.131
# La prediccion para Crimson Tide (1995) es: 4.131
# La prediccion para Crumb (1994) es: 4.131
# La prediccion para Desperado (1995) es: 4.131
# La prediccion para Devil in a Blue Dress (1995) es: 4.131
# La prediccion para Die Hard: With a Vengeance (1995) es: 4.131
# La prediccion para Doom Generation, The (1995) es: 4.131
# La prediccion para First Knight (1995) es: 4.131
# La prediccion para Free Willy 2: The Adventure Home (1995) es: 4.131
# La prediccion para Hackers (1995) es: 4.131
# La prediccion para Jeffrey (1995) es: 4.131
# La prediccion para Johnny Mnemonic (1995) es: 4.131
# La prediccion para Judge Dredd (1995) es: 4.131
# La prediccion para Jury Duty (1995) es: 4.131
# La prediccion para Kids (1995) es: 3.500
# La prediccion para Living in Oblivion (1995) es: 4.131
# La prediccion para Lord of Illusions (1995) es: 4.131
# La prediccion para Love & Human Remains (1993) es: 4.131
# La prediccion para Mad Love (1995) es: 4.131
# La prediccion para Mallrats (1995) es: 4.131
# La prediccion para Mighty Morphin Power Rangers: The Movie (1995) es: 4.131
# La prediccion para Mute Witness (1994) es: 4.131
# La prediccion para Nadja (1994) es: 4.131
# La prediccion para Net, The (1995) es: 4.131
# La prediccion para Nine Months (1995) es: 4.131
# La prediccion para Party Girl (1995) es: 4.131
# La prediccion para Prophecy, The (1995) es: 4.131
# La prediccion para Reckless (1995) es: 4.131
# La prediccion para Safe (1995) es: 4.131
# La prediccion para Scarlet Letter, The (1995) es: 4.131
# La prediccion para Showgirls (1995) es: 4.131
# La prediccion para Smoke (1995) es: 4.131
# La prediccion para Something to Talk About (1995) es: 4.131
# La prediccion para Species (1995) es: 4.131
# La prediccion para Strange Days (1995) es: 4.131
# La prediccion para Umbrellas of Cherbourg, The (Parapluies de Cherbourg, Les) (1964) es: 4.131
# La prediccion para Three Wishes (1995) es: 4.131
# La prediccion para Total Eclipse (1995) es: 4.131
# La prediccion para To Wong Foo, Thanks for Everything! Julie Newmar (1995) es: 4.131
# La prediccion para Under Siege 2: Dark Territory (1995) es: 4.131
# La prediccion para Unstrung Heroes (1995) es: 4.131
# La prediccion para Unzipped (1995) es: 4.131
# La prediccion para Walk in the Clouds, A (1995) es: 4.131
# La prediccion para Waterworld (1995) es: 4.131
# La prediccion para White Man's Burden (1995) es: 4.131
# La prediccion para Wild Bill (1995) es: 4.131
# La prediccion para Browning Version, The (1994) es: 4.131
# La prediccion para Bushwhacked (1995) es: 4.131
# La prediccion para Burnt by the Sun (Utomlyonnye solntsem) (1994) es: 4.131
# La prediccion para Before the Rain (Pred dozhdot) (1994) es: 4.131
# La prediccion para Before Sunrise (1995) es: 4.131
# La prediccion para Billy Madison (1995) es: 4.000
# La prediccion para Babysitter, The (1995) es: 4.131
# La prediccion para Boys on the Side (1995) es: 4.131
# La prediccion para Cure, The (1995) es: 4.131
# La prediccion para Castle Freak (1995) es: 4.131
# La prediccion para Circle of Friends (1995) es: 4.131
# La prediccion para Clerks (1994) es: 4.100
# La prediccion para Don Juan DeMarco (1995) es: 4.131
# La prediccion para Disclosure (1994) es: 4.131
# La prediccion para Drop Zone (1994) es: 4.131
# La prediccion para Destiny Turns on the Radio (1995) es: 4.131
# La prediccion para Death and the Maiden (1994) es: 4.131
# La prediccion para Dolores Claiborne (1995) es: 4.131
# La prediccion para Dumb & Dumber (Dumb and Dumber) (1994) es: 4.131
# La prediccion para Eat Drink Man Woman (Yin shi nan nu) (1994) es: 4.131
# La prediccion para Exotica (1994) es: 4.131
# La prediccion para Exit to Eden (1994) es: 4.131
# La prediccion para Ed Wood (1994) es: 4.131
# La prediccion para French Kiss (1995) es: 4.131
# La prediccion para Forget Paris (1995) es: 4.131
# La prediccion para Far From Home: The Adventures of Yellow Dog (1995) es: 4.131
# La prediccion para Goofy Movie, A (1995) es: 4.131
# La prediccion para Hideaway (1995) es: 4.131
# La prediccion para Fluke (1995) es: 4.131
# La prediccion para Farinelli: il castrato (1994) es: 4.131
# La prediccion para Gordy (1995) es: 4.131
# La prediccion para Hoop Dreams (1994) es: 4.131
# La prediccion para Heavenly Creatures (1994) es: 4.131
# La prediccion para Houseguest (1994) es: 4.131
# La prediccion para Immortal Beloved (1994) es: 4.131
# La prediccion para Heavyweights (Heavy Weights) (1995) es: 4.131
# La prediccion para Hunted, The (1995) es: 4.131
# La prediccion para I.Q. (1994) es: 4.131
# La prediccion para Interview with the Vampire: The Vampire Chronicles (1994) es: 4.131
# La prediccion para Jefferson in Paris (1995) es: 4.131
# La prediccion para Jerky Boys, The (1995) es: 4.131
# La prediccion para Junior (1994) es: 4.131
# La prediccion para Just Cause (1995) es: 4.131
# La prediccion para Kid in King Arthur's Court, A (1995) es: 4.131
# La prediccion para Kiss of Death (1995) es: 4.131
# La prediccion para Little Women (1994) es: 4.131
# La prediccion para Little Princess, A (1995) es: 4.131
# La prediccion para Ladybird Ladybird (1994) es: 4.131
# La prediccion para Like Water for Chocolate (Como agua para chocolate) (1992) es: 4.131
# La prediccion para Legends of the Fall (1994) es: 4.131
# La prediccion para Major Payne (1995) es: 4.131
# La prediccion para My Crazy Life (Mi vida loca) (1993) es: 4.131
# La prediccion para Love Affair (1994) es: 4.131
# La prediccion para Losing Isaiah (1995) es: 4.131
# La prediccion para Madness of King George, The (1994) es: 4.131
# La prediccion para Mary Shelley's Frankenstein (Frankenstein) (1994) es: 4.131
# La prediccion para Man of the House (1995) es: 4.131
# La prediccion para Mixed Nuts (1994) es: 4.131
# La prediccion para Milk Money (1994) es: 4.131
# La prediccion para Miracle on 34th Street (1994) es: 4.131
# La prediccion para Miami Rhapsody (1995) es: 4.131
# La prediccion para My Family (1995) es: 4.131
# La prediccion para Murder in the First (1995) es: 4.131
# La prediccion para Nobody's Fool (1994) es: 4.131
# La prediccion para Nell (1994) es: 4.131
# La prediccion para New Jersey Drive (1995) es: 4.131
# La prediccion para New York Cop (Nyû Yôku no koppu) (1993) es: 4.131
# La prediccion para Beyond Bedlam (1993) es: 4.131
# La prediccion para Nina Takes a Lover (1994) es: 4.131
# La prediccion para Natural Born Killers (1994) es: 4.167
# La prediccion para Only You (1994) es: 4.131
# La prediccion para Once Were Warriors (1994) es: 4.131
# La prediccion para Poison Ivy II (1996) es: 4.131
# La prediccion para Outbreak (1995) es: 4.131
# La prediccion para Perez Family, The (1995) es: 4.131
# La prediccion para Pyromaniac's Love Story, A (1995) es: 4.131
# La prediccion para Pushing Hands (Tui shou) (1992) es: 4.131
# La prediccion para Priest (1994) es: 4.131
# La prediccion para Quiz Show (1994) es: 4.131
# La prediccion para Picture Bride (Bijo photo) (1994) es: 4.131
# La prediccion para Queen Margot (Reine Margot, La) (1994) es: 4.131
# La prediccion para Quick and the Dead, The (1995) es: 4.131
# La prediccion para Roommates (1995) es: 4.131
# La prediccion para Ready to Wear (Pret-A-Porter) (1994) es: 4.131
# La prediccion para Three Colors: Red (Trois couleurs: Rouge) (1994) es: 4.131
# La prediccion para Three Colors: Blue (Trois couleurs: Bleu) (1993) es: 4.131
# La prediccion para Three Colors: White (Trzy kolory: Bialy) (1994) es: 4.131
# La prediccion para Rent-a-Kid (1995) es: 4.131
# La prediccion para Relative Fear (1994) es: 4.131
# La prediccion para Stuart Saves His Family (1995) es: 4.131
# La prediccion para Swan Princess, The (1994) es: 4.131
# La prediccion para Secret of Roan Inish, The (1994) es: 4.131
# La prediccion para Specialist, The (1994) es: 4.131
# La prediccion para Stargate (1994) es: 4.131
# La prediccion para Santa Clause, The (1994) es: 4.131
# La prediccion para Shallow Grave (1994) es: 4.131
# La prediccion para Suture (1993) es: 4.131
# La prediccion para Strawberry and Chocolate (Fresa y chocolate) (1993) es: 4.131
# La prediccion para Swimming with Sharks (1995) es: 4.131
# La prediccion para Sum of Us, The (1994) es: 4.131
# La prediccion para National Lampoon's Senior Trip (1995) es: 4.131
# La prediccion para To Live (Huozhe) (1994) es: 4.131
# La prediccion para Tank Girl (1995) es: 4.131
# La prediccion para Tales from the Crypt Presents: Demon Knight (1995) es: 4.131
# La prediccion para Star Trek: Generations (1994) es: 4.131
# La prediccion para Tales from the Hood (1995) es: 4.131
# La prediccion para Tom & Viv (1994) es: 4.131
# La prediccion para Village of the Damned (1995) es: 4.131
# La prediccion para Tommy Boy (1995) es: 4.131
# La prediccion para Vanya on 42nd Street (1994) es: 4.131
# La prediccion para Underneath (1995) es: 4.131
# La prediccion para Walking Dead, The (1995) es: 4.131
# La prediccion para What's Eating Gilbert Grape (1993) es: 4.131
# La prediccion para Virtuosity (1995) es: 4.131
# La prediccion para While You Were Sleeping (1995) es: 4.131
# La prediccion para War, The (1994) es: 4.131
# La prediccion para Double Happiness (1994) es: 4.131
# La prediccion para Muriel's Wedding (1994) es: 4.131
# La prediccion para Baby-Sitters Club, The (1995) es: 4.131
# La prediccion para Adventures of Priscilla, Queen of the Desert, The (1994) es: 4.131
# La prediccion para Backbeat (1993) es: 4.131
# La prediccion para Bitter Moon (1992) es: 4.131
# La prediccion para Bullets Over Broadway (1994) es: 4.131
# La prediccion para Clear and Present Danger (1994) es: 4.131
# La prediccion para Client, The (1994) es: 4.131
# La prediccion para Corrina, Corrina (1994) es: 4.131
# La prediccion para Crooklyn (1994) es: 4.131
# La prediccion para Crow, The (1994) es: 4.131
# La prediccion para Cobb (1994) es: 4.131
# La prediccion para Flintstones, The (1994) es: 4.131
# La prediccion para Four Weddings and a Funeral (1994) es: 4.131
# La prediccion para Higher Learning (1995) es: 4.131
# La prediccion para I Like It Like That (1994) es: 4.131
# La prediccion para I Love Trouble (1994) es: 4.131
# La prediccion para It Could Happen to You (1994) es: 4.131
# La prediccion para Jungle Book, The (1994) es: 4.131
# La prediccion para Wonderful, Horrible Life of Leni Riefenstahl, The (Macht der Bilder: Leni Riefenstahl, Die) (1993) es: 4.131
# La prediccion para Lion King, The (1994) es: 4.000
# La prediccion para Little Buddha (1993) es: 4.131
# La prediccion para Wes Craven's New Nightmare (Nightmare on Elm Street Part 7: Freddy's Finale, A) (1994) es: 4.131
# La prediccion para Mask, The (1994) es: 4.131
# La prediccion para Maverick (1994) es: 4.131
# La prediccion para Mrs. Parker and the Vicious Circle (1994) es: 4.131
# La prediccion para Naked Gun 33 1/3: The Final Insult (1994) es: 4.131
# La prediccion para Paper, The (1994) es: 4.131
# La prediccion para Reality Bites (1994) es: 4.131
# La prediccion para Red Rock West (1992) es: 4.131
# La prediccion para Richie Rich (1994) es: 4.131
# La prediccion para River Wild, The (1994) es: 4.131
# La prediccion para Speed (1994) es: 4.131
# La prediccion para Speechless (1994) es: 4.131
# La prediccion para Timecop (1994) es: 4.131
# La prediccion para True Lies (1994) es: 4.131
# La prediccion para When a Man Loves a Woman (1994) es: 4.131
# La prediccion para Wolf (1994) es: 4.131
# La prediccion para Wyatt Earp (1994) es: 4.131
# La prediccion para Bad Company (1995) es: 4.131
# La prediccion para Man of No Importance, A (1994) es: 4.131
# La prediccion para S.F.W. (1994) es: 4.131
# La prediccion para Low Down Dirty Shame, A (1994) es: 4.131
# La prediccion para Boys Life (1995) es: 4.131
# La prediccion para Colonel Chabert, Le (1994) es: 4.131
# La prediccion para Faster Pussycat! Kill! Kill! (1965) es: 4.131
# La prediccion para Jason's Lyric (1994) es: 4.131
# La prediccion para Street Fighter (1994) es: 4.131
# La prediccion para Highlander III: The Sorcerer (a.k.a. Highlander: The Final Dimension) (1994) es: 4.131
# La prediccion para Federal Hill (1994) es: 4.131
# La prediccion para In the Mouth of Madness (1995) es: 4.131
# La prediccion para 8 Seconds (1994) es: 4.131
# La prediccion para Above the Rim (1994) es: 4.131
# La prediccion para Age of Innocence, The (1993) es: 4.131
# La prediccion para Airheads (1994) es: 4.131
# La prediccion para Air Up There, The (1994) es: 4.131
# La prediccion para Another Stakeout (1993) es: 4.131
# La prediccion para Bad Girls (1994) es: 4.131
# La prediccion para Barcelona (1994) es: 4.131
# La prediccion para Being Human (1993) es: 4.131
# La prediccion para Beverly Hillbillies, The (1993) es: 4.131
# La prediccion para Beverly Hills Cop III (1994) es: 4.131
# La prediccion para Black Beauty (1994) es: 4.131
# La prediccion para Blink (1994) es: 4.131
# La prediccion para Blown Away (1994) es: 4.131
# La prediccion para Blue Chips (1994) es: 4.131
# La prediccion para Blue Sky (1994) es: 4.131
# La prediccion para Body Snatchers (1993) es: 4.131
# La prediccion para Boxing Helena (1993) es: 4.131
# La prediccion para Bronx Tale, A (1993) es: 4.131
# La prediccion para Cabin Boy (1994) es: 4.131
# La prediccion para Calendar Girl (1993) es: 4.131
# La prediccion para Carlito's Way (1993) es: 4.833
# La prediccion para City Slickers II: The Legend of Curly's Gold (1994) es: 4.131
# La prediccion para Clean Slate (1994) es: 4.131
# La prediccion para Cliffhanger (1993) es: 4.131
# La prediccion para Coneheads (1993) es: 4.131
# La prediccion para Color of Night (1994) es: 4.131
# La prediccion para Cops and Robbersons (1994) es: 4.131
# La prediccion para Cowboy Way, The (1994) es: 4.131
# La prediccion para Dave (1993) es: 4.131
# La prediccion para Dazed and Confused (1993) es: 4.131
# La prediccion para Demolition Man (1993) es: 4.131
# La prediccion para Even Cowgirls Get the Blues (1993) es: 4.131
# La prediccion para Fatal Instinct (1993) es: 4.131
# La prediccion para Farewell My Concubine (Ba wang bie ji) (1993) es: 4.131
# La prediccion para Fearless (1993) es: 4.131
# La prediccion para Fear of a Black Hat (1994) es: 4.131
# La prediccion para With Honors (1994) es: 4.131
# La prediccion para Flesh and Bone (1993) es: 4.131
# La prediccion para Widows' Peak (1994) es: 4.131
# La prediccion para For Love or Money (1993) es: 4.131
# La prediccion para Firm, The (1993) es: 4.131
# La prediccion para Free Willy (1993) es: 4.131
# La prediccion para Fresh (1994) es: 4.131
# La prediccion para Fugitive, The (1993) es: 4.131
# La prediccion para Geronimo: An American Legend (1993) es: 4.131
# La prediccion para Getaway, The (1994) es: 4.131
# La prediccion para Getting Even with Dad (1994) es: 4.131
# La prediccion para Go Fish (1994) es: 4.131
# La prediccion para Hard Target (1993) es: 4.131
# La prediccion para Hot Shots! Part Deux (1993) es: 4.131
# La prediccion para Live Nude Girls (1995) es: 4.131
# La prediccion para Englishman Who Went Up a Hill But Came Down a Mountain, The (1995) es: 4.131
# La prediccion para House of the Spirits, The (1993) es: 4.131
# La prediccion para House Party 3 (1994) es: 4.131
# La prediccion para Hudsucker Proxy, The (1994) es: 4.131
# La prediccion para I'll Do Anything (1994) es: 4.131
# La prediccion para In the Army Now (1994) es: 4.131
# La prediccion para In the Line of Fire (1993) es: 4.131
# La prediccion para In the Name of the Father (1993) es: 4.131
# La prediccion para Inkwell, The (1994) es: 4.131
# La prediccion para What's Love Got to Do with It? (1993) es: 4.131
# La prediccion para Jimmy Hollywood (1994) es: 4.131
# La prediccion para Judgment Night (1993) es: 4.131
# La prediccion para Jurassic Park (1993) es: 4.131
# La prediccion para Kalifornia (1993) es: 4.131
# La prediccion para Killing Zoe (1994) es: 4.131
# La prediccion para Lassie (1994) es: 4.131
# La prediccion para Last Action Hero (1993) es: 4.131
# La prediccion para Life with Mikey (1993) es: 4.131
# La prediccion para Lightning Jack (1994) es: 4.131
# La lista es empty
# La prediccion para Made in America (1993) es: 4.131
# La prediccion para Malice (1993) es: 4.131
# La prediccion para Man Without a Face, The (1993) es: 4.131
# La prediccion para Manhattan Murder Mystery (1993) es: 4.131
# La prediccion para Menace II Society (1993) es: 4.131
# La prediccion para Executive Decision (1996) es: 4.131
# La prediccion para In the Realm of the Senses (Ai no corrida) (1976) es: 4.131
# La prediccion para What Happened Was... (1994) es: 4.131
# La prediccion para Much Ado About Nothing (1993) es: 4.131
# La prediccion para Mr. Wonderful (1993) es: 4.131
# La prediccion para Mrs. Doubtfire (1993) es: 4.131
# La prediccion para Naked (1993) es: 4.131
# La prediccion para Next Karate Kid, The (1994) es: 4.131
# La prediccion para No Escape (1994) es: 4.131
# La prediccion para North (1994) es: 4.131
# La prediccion para Orlando (1992) es: 4.131
# La prediccion para Perfect World, A (1993) es: 4.131
# La prediccion para Philadelphia (1993) es: 4.131
# La prediccion para Piano, The (1993) es: 4.131
# La prediccion para Poetic Justice (1993) es: 4.131
# La prediccion para Program, The (1993) es: 4.131
# La prediccion para Puppet Masters, The (1994) es: 4.131
# La prediccion para Radioland Murders (1994) es: 4.131
# La prediccion para Ref, The (1994) es: 4.131
# La prediccion para Remains of the Day, The (1993) es: 4.131
# La prediccion para Renaissance Man (1994) es: 4.131
# La prediccion para Rising Sun (1993) es: 4.131
# La prediccion para Road to Wellville, The (1994) es: 4.131
# La prediccion para RoboCop 3 (1993) es: 4.131
# La prediccion para Robin Hood: Men in Tights (1993) es: 4.131
# La prediccion para Romeo Is Bleeding (1993) es: 4.131
# La prediccion para Romper Stomper (1992) es: 4.131
# La prediccion para Ruby in Paradise (1993) es: 4.131
# La prediccion para Rudy (1993) es: 4.131
# La prediccion para Savage Nights (Nuits fauves, Les) (1992) es: 4.131
# La prediccion para Scout, The (1994) es: 4.131
# La prediccion para Searching for Bobby Fischer (1993) es: 4.131
# La prediccion para Secret Garden, The (1993) es: 4.131
# La prediccion para Serial Mom (1994) es: 4.131
# La prediccion para Shadow, The (1994) es: 4.131
# La prediccion para Shadowlands (1993) es: 4.131
# La prediccion para Short Cuts (1993) es: 4.131
# La prediccion para Simple Twist of Fate, A (1994) es: 4.131
# La prediccion para Sirens (1994) es: 4.131
# La prediccion para Six Degrees of Separation (1993) es: 4.131
# La prediccion para Sleepless in Seattle (1993) es: 4.131
# La prediccion para Sliver (1993) es: 4.131
# La prediccion para Blade Runner (1982) es: 4.667
# La prediccion para Son in Law (1993) es: 4.131
# La prediccion para So I Married an Axe Murderer (1993) es: 4.131
# La prediccion para Striking Distance (1993) es: 4.131
# La prediccion para Super Mario Bros. (1993) es: 4.131
# La prediccion para Surviving the Game (1994) es: 4.131
# La prediccion para Terminal Velocity (1994) es: 4.131
# La prediccion para Thirty-Two Short Films About Glenn Gould (1993) es: 4.131
# La prediccion para Threesome (1994) es: 4.131
# La prediccion para Nightmare Before Christmas, The (1993) es: 4.131
# La prediccion para Three Musketeers, The (1993) es: 4.131
# La prediccion para Tombstone (1993) es: 4.131
# La prediccion para True Romance (1993) es: 4.131
# La prediccion para War Room, The (1993) es: 3.500
# La prediccion para Pagemaster, The (1994) es: 4.131
# La prediccion para Welcome to the Dollhouse (1995) es: 4.131
# La prediccion para Germinal (1993) es: 4.131
# La prediccion para Chasers (1994) es: 4.131
# La prediccion para Kika (1993) es: 4.131
# La prediccion para Bhaji on the Beach (1993) es: 4.131
# La prediccion para Little Big League (1994) es: 4.131
# La prediccion para Ciao, Professore! (Io speriamo che me la cavo) (1992) es: 4.131
# La prediccion para Spanking the Monkey (1994) es: 4.131
# La prediccion para Little Rascals, The (1994) es: 4.131
# La prediccion para Andre (1994) es: 4.131
# La prediccion para Escort, The (Scorta, La) (1993) es: 4.131
# La prediccion para Princess Caraboo (1994) es: 4.131
# La prediccion para Celluloid Closet, The (1995) es: 4.131
# La prediccion para Dear Diary (Caro Diario) (1994) es: 4.131
# La prediccion para Brady Bunch Movie, The (1995) es: 4.131
# La prediccion para Ghost (1990) es: 1.000
# La prediccion para Aladdin (1992) es: 3.000
# La prediccion para Terminator 2: Judgment Day (1991) es: 4.500
# La prediccion para Dances with Wolves (1990) es: 4.131
# La prediccion para Batman (1989) es: 3.583
# La prediccion para Snow White and the Seven Dwarfs (1937) es: 3.000
# La prediccion para Beauty and the Beast (1991) es: 3.000
# La prediccion para Pinocchio (1940) es: 3.000
# La prediccion para Pretty Woman (1990) es: 4.131
# La prediccion para Wild Bunch, The (1969) es: 4.131
# La prediccion para Love and a .45 (1994) es: 4.131
# La prediccion para Great Day in Harlem, A (1994) es: 4.131
# La prediccion para One Fine Day (1996) es: 4.131
# La prediccion para Candyman: Farewell to the Flesh (1995) es: 4.131
# La prediccion para Fargo (1996) es: 4.000
# La prediccion para Homeward Bound II: Lost in San Francisco (1996) es: 4.131
# La prediccion para Heavy Metal (1981) es: 4.131
# La prediccion para Hellraiser: Bloodline (1996) es: 4.131
# La prediccion para Pallbearer, The (1996) es: 4.131
# La prediccion para Jane Eyre (1996) es: 4.131
# La prediccion para Bread and Chocolate (Pane e cioccolata) (1973) es: 4.131
# La prediccion para Aristocats, The (1970) es: 3.000
# La prediccion para Flower of My Secret, The (La flor de mi secreto) (1995) es: 4.131
# La prediccion para Two Much (1995) es: 4.131
# La prediccion para Ed (1996) es: 4.131
# La prediccion para Thin Line Between Love and Hate, A (1996) es: 4.131
# La prediccion para Last Supper, The (1995) es: 4.131
# La prediccion para Primal Fear (1996) es: 4.131
# La prediccion para All Dogs Go to Heaven 2 (1996) es: 4.131
# La prediccion para Land and Freedom (Tierra y libertad) (1995) es: 4.131
# La prediccion para Denise Calls Up (1995) es: 4.131
# La prediccion para Theodore Rex (1995) es: 4.131
# La prediccion para Family Thing, A (1996) es: 4.131
# La prediccion para Frisk (1995) es: 4.131
# La prediccion para Sgt. Bilko (1996) es: 4.131
# La lista es empty
# La prediccion para Girl 6 (1996) es: 4.131
# La prediccion para Diabolique (1996) es: 4.131
# La prediccion para Nelly & Monsieur Arnaud (1995) es: 4.131
# La prediccion para Courage Under Fire (1996) es: 4.131
# La prediccion para Mission: Impossible (1996) es: 4.131
# La prediccion para Cold Fever (Á köldum klaka) (1995) es: 4.131
# La prediccion para Moll Flanders (1996) es: 4.131
# La prediccion para Dragonheart (1996) es: 4.131
# La prediccion para Eddie (1996) es: 4.131
# La prediccion para James and the Giant Peach (1996) es: 4.131
# La prediccion para Fear (1996) es: 4.131
# La prediccion para Kids in the Hall: Brain Candy (1996) es: 4.131
# La prediccion para Underground (1995) es: 4.131
# La prediccion para Bloodsport 2 (a.k.a. Bloodsport II: The Next Kumite) (1996) es: 4.131
# La prediccion para Song of the Little Road (Pather Panchali) (1955) es: 4.131
# La prediccion para World of Apu, The (Apur Sansar) (1959) es: 4.131
# La prediccion para Mystery Science Theater 3000: The Movie (1996) es: 4.131
# La prediccion para Space Jam (1996) es: 4.131
# La prediccion para Barbarella (1968) es: 4.131
# La prediccion para Some Folks Call It a Sling Blade (1993) es: 4.131
# La prediccion para Run of the Country, The (1995) es: 4.131
# La prediccion para Alphaville (Alphaville, une étrange aventure de Lemmy Caution) (1965) es: 4.131
# La prediccion para It's My Party (1996) es: 4.131
# La prediccion para Operation Dumbo Drop (1995) es: 4.131
# La prediccion para Mrs. Winterbourne (1996) es: 4.131
# La prediccion para Solo (1996) es: 4.131
# La prediccion para Substitute, The (1996) es: 4.131
# La prediccion para True Crime (1996) es: 4.131
# La prediccion para Feeling Minnesota (1996) es: 4.131
# La prediccion para Delta of Venus (1995) es: 4.131
# La prediccion para Angus (1995) es: 4.131
# La prediccion para Boys (1996) es: 4.131
# La prediccion para Quest, The (1996) es: 4.131
# La prediccion para Sunset Park (1996) es: 4.131
# La prediccion para Mulholland Falls (1996) es: 4.131
# La prediccion para Truth About Cats & Dogs, The (1996) es: 4.131
# La prediccion para Oliver & Company (1988) es: 4.131
# La prediccion para Celtic Pride (1996) es: 4.131
# La prediccion para Flipper (1996) es: 4.131
# La prediccion para Dead Man (1995) es: 4.131
# La prediccion para Horseman on the Roof, The (Hussard sur le toit, Le) (1995) es: 4.131
# La prediccion para Visitors, The (Visiteurs, Les) (1993) es: 4.131
# La prediccion para Multiplicity (1996) es: 4.131
# La prediccion para Wallace & Gromit: The Best of Aardman Animation (1996) es: 4.131
# La prediccion para Haunted World of Edward D. Wood Jr., The (1996) es: 4.131
# La prediccion para Craft, The (1996) es: 4.131
# La prediccion para Great White Hype, The (1996) es: 4.131
# La prediccion para Last Dance (1996) es: 4.131
# La prediccion para Cold Comfort Farm (1995) es: 4.131
# La prediccion para Heaven's Prisoners (1996) es: 4.131
# La prediccion para Rock, The (1996) es: 4.131
# La prediccion para Cemetery Man (Dellamorte Dellamore) (1994) es: 4.131
# La prediccion para Twister (1996) es: 4.131
# La prediccion para Barb Wire (1996) es: 4.131
# La prediccion para Ghost in the Shell (Kôkaku kidôtai) (1995) es: 4.131
# La prediccion para Thinner (1996) es: 4.131
# La prediccion para Spy Hard (1996) es: 4.131
# La prediccion para Wallace & Gromit: A Close Shave (1995) es: 4.131
# La prediccion para Stupids, The (1996) es: 4.131
# La prediccion para Arrival, The (1996) es: 4.131
# La prediccion para Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1964) es: 4.250
# La prediccion para Ashes of Time (Dung che sai duk) (1994) es: 4.131
# La prediccion para Maya Lin: A Strong Clear Vision (1994) es: 4.131
# La prediccion para Stalingrad (1993) es: 4.131
# La prediccion para Phantom, The (1996) es: 4.131
# La prediccion para Striptease (1996) es: 4.131
# La prediccion para Heavy (1995) es: 4.131
# La prediccion para Jack (1996) es: 4.131
# La prediccion para I Shot Andy Warhol (1996) es: 4.131
# La prediccion para Touki Bouki (1973) es: 4.131
# La prediccion para Spirits of the Dead (1968) es: 4.131
# La prediccion para 'Til There Was You (1997) es: 4.131
# La prediccion para Independence Day (a.k.a. ID4) (1996) es: 4.131
# La prediccion para Stealing Beauty (1996) es: 4.131
# La prediccion para Fan, The (1996) es: 4.131
# La prediccion para Hunchback of Notre Dame, The (1996) es: 4.131
# La prediccion para Cable Guy, The (1996) es: 4.131
# La prediccion para Kingpin (1996) es: 4.131
# La prediccion para Eraser (1996) es: 4.131
# La prediccion para Nutty Professor, The (1996) es: 4.131
# La prediccion para Unforgettable Summer, An (Un été inoubliable) (1994) es: 4.131
# La prediccion para Last Klezmer: Leopold Kozlowski, His Life and Music, The (1994) es: 4.131
# La prediccion para Somebody to Love (1994) es: 4.131
# La prediccion para Daylight (1996) es: 4.131
# La prediccion para Frighteners, The (1996) es: 4.131
# La prediccion para Lone Star (1996) es: 4.131
# La prediccion para Harriet the Spy (1996) es: 4.131
# La prediccion para Phenomenon (1996) es: 4.131
# La prediccion para Walking and Talking (1996) es: 4.131
# La prediccion para She's the One (1996) es: 4.131
# La prediccion para Time to Kill, A (1996) es: 4.131
# La prediccion para American Buffalo (1996) es: 4.131
# La prediccion para Alaska (1996) es: 4.131
# La prediccion para Fled (1996) es: 4.131
# La prediccion para Kazaam (1996) es: 4.131
# La prediccion para Larger Than Life (1996) es: 4.131
# La prediccion para Very Brady Sequel, A (1996) es: 4.131
# La prediccion para Collector, The (La collectionneuse) (1967) es: 4.131
# La prediccion para Kaspar Hauser (1993) es: 4.131
# La prediccion para Adventures of Pinocchio, The (1996) es: 4.131
# La prediccion para Joe's Apartment (1996) es: 4.131
# La prediccion para First Wives Club, The (1996) es: 4.131
# La prediccion para Ransom (1996) es: 4.500
# La prediccion para High School High (1996) es: 4.131
# La prediccion para Foxfire (1996) es: 4.131
# La prediccion para Chain Reaction (1996) es: 4.131
# La prediccion para Matilda (1996) es: 4.131
# La prediccion para Emma (1996) es: 4.131
# La prediccion para Crow: City of Angels, The (1996) es: 4.131
# La prediccion para House Arrest (1996) es: 4.131
# La prediccion para Eyes Without a Face (Yeux sans visage, Les) (1959) es: 4.131
# La prediccion para Tales from the Crypt Presents: Bordello of Blood (1996) es: 4.131
# La prediccion para Spitfire Grill, The (1996) es: 4.131
# La prediccion para Escape from L.A. (1996) es: 4.131
# La prediccion para Basquiat (1996) es: 4.131
# La prediccion para Tin Cup (1996) es: 4.131
# La prediccion para Supercop (Police Story 3: Supercop) (Jing cha gu shi III: Chao ji jing cha) (1992) es: 4.131
# La prediccion para Bound (1996) es: 4.131
# La prediccion para Carpool (1996) es: 4.131
# La prediccion para Kansas City (1996) es: 4.131
# La prediccion para Gone Fishin' (1997) es: 4.131
# La prediccion para Nothing to Lose (1994) es: 4.131
# La prediccion para Supercop 2 (Project S) (Chao ji ji hua) (1993) es: 4.131
# La prediccion para Relic, The (1997) es: 4.131
# La prediccion para Island of Dr. Moreau, The (1996) es: 4.131
# La prediccion para First Kid (1996) es: 4.131
# La prediccion para Trigger Effect, The (1996) es: 4.131
# La prediccion para Bogus (1996) es: 4.131
# La prediccion para Bulletproof (1996) es: 4.131
# La prediccion para Land Before Time III: The Time of the Great Giving (1995) es: 4.131
# La prediccion para 1-900 (06) (1994) es: 4.131
# La prediccion para Halloween: The Curse of Michael Myers (Halloween 6: The Curse of Michael Myers) (1995) es: 4.131
# La prediccion para Twelfth Night (1996) es: 4.131
# La prediccion para Mother Night (1996) es: 4.131
# La prediccion para Wild Reeds (Les roseaux sauvages) (1994) es: 4.131
# La prediccion para For Whom the Bell Tolls (1943) es: 4.131
# La prediccion para Philadelphia Story, The (1940) es: 4.131
# La prediccion para Singin' in the Rain (1952) es: 4.131
# La prediccion para American in Paris, An (1951) es: 4.131
# La prediccion para Funny Face (1957) es: 4.131
# La prediccion para Breakfast at Tiffany's (1961) es: 4.131
# La prediccion para Vertigo (1958) es: 4.500
# La prediccion para Rear Window (1954) es: 4.000
# La prediccion para It Happened One Night (1934) es: 4.131
# La prediccion para Gaslight (1944) es: 4.131
# La prediccion para Gay Divorcee, The (1934) es: 4.131
# La prediccion para North by Northwest (1959) es: 4.500
# La prediccion para Apartment, The (1960) es: 4.131
# La prediccion para Some Like It Hot (1959) es: 4.131
# La prediccion para Charade (1963) es: 4.131
# La prediccion para Casablanca (1942) es: 4.131
# La prediccion para Maltese Falcon, The (1941) es: 4.131
# La prediccion para My Fair Lady (1964) es: 4.131
# La prediccion para Sabrina (1954) es: 4.131
# La prediccion para Roman Holiday (1953) es: 4.131
# La prediccion para Little Princess, The (1939) es: 4.131
# La prediccion para Meet Me in St. Louis (1944) es: 4.131
# La prediccion para Wizard of Oz, The (1939) es: 4.131
# La prediccion para Gone with the Wind (1939) es: 4.131
# La prediccion para My Favorite Year (1982) es: 4.131
# La prediccion para Sunset Blvd. (a.k.a. Sunset Boulevard) (1950) es: 4.131
# La prediccion para Citizen Kane (1941) es: 4.131
# La prediccion para 2001: A Space Odyssey (1968) es: 4.038
# La prediccion para All About Eve (1950) es: 4.131
# La prediccion para Women, The (1939) es: 4.131
# La prediccion para Rebecca (1940) es: 4.131
# La lista es empty
# La prediccion para Notorious (1946) es: 4.131
# La prediccion para Spellbound (1945) es: 4.131
# La prediccion para Affair to Remember, An (1957) es: 4.131
# La prediccion para To Catch a Thief (1955) es: 4.131
# La prediccion para Father of the Bride (1950) es: 4.131
# La prediccion para Band Wagon, The (1953) es: 4.131
# La prediccion para Ninotchka (1939) es: 4.131
# La prediccion para Love in the Afternoon (1957) es: 4.131
# La prediccion para Gigi (1958) es: 4.131
# La prediccion para Adventures of Robin Hood, The (1938) es: 4.131
# La prediccion para Mark of Zorro, The (1940) es: 4.131
# La prediccion para Laura (1944) es: 4.131
# La prediccion para Ghost and Mrs. Muir, The (1947) es: 4.131
# La prediccion para Lost Horizon (1937) es: 4.131
# La prediccion para Top Hat (1935) es: 4.131
# La prediccion para To Be or Not to Be (1942) es: 4.131
# La prediccion para My Man Godfrey (1936) es: 4.131
# La prediccion para Giant (1956) es: 4.131
# La prediccion para East of Eden (1955) es: 4.131
# La prediccion para Thin Man, The (1934) es: 4.131
# La prediccion para His Girl Friday (1940) es: 4.131
# La prediccion para Around the World in 80 Days (1956) es: 4.131
# La prediccion para It's a Wonderful Life (1946) es: 4.131
# La prediccion para Mr. Smith Goes to Washington (1939) es: 3.500
# La prediccion para Bringing Up Baby (1938) es: 4.131
# La lista es empty
# La prediccion para Of Human Bondage (1934) es: 4.131
# La prediccion para Little Lord Fauntleroy (1936) es: 4.131
# La prediccion para Inspector General, The (1949) es: 4.131
# La prediccion para 39 Steps, The (1935) es: 4.131
# La prediccion para Night of the Living Dead (1968) es: 4.131
# La prediccion para African Queen, The (1951) es: 4.131
# La lista es empty
# La prediccion para Cat on a Hot Tin Roof (1958) es: 4.131
# La prediccion para Meet John Doe (1941) es: 4.131
# La lista es empty
# La prediccion para Nothing Personal (1995) es: 4.131
# La prediccion para Dangerous Ground (1997) es: 4.131
# La prediccion para Picnic (1955) es: 4.131
# La prediccion para Pompatus of Love, The (1996) es: 4.131
# La prediccion para Fly Away Home (1996) es: 4.131
# La prediccion para Bliss (1997) es: 4.131
# La prediccion para Grace of My Heart (1996) es: 4.131
# La prediccion para Maximum Risk (1996) es: 4.131
# La prediccion para Michael Collins (1996) es: 4.131
# La prediccion para Infinity (1996) es: 4.131
# La prediccion para Big Night (1996) es: 4.131
# La prediccion para Last Man Standing (1996) es: 4.131
# La prediccion para Set It Off (1996) es: 4.131
# La prediccion para 2 Days in the Valley (1996) es: 4.131
# La prediccion para Extreme Measures (1996) es: 4.131
# La prediccion para Glimmer Man, The (1996) es: 4.131
# La prediccion para D3: The Mighty Ducks (1996) es: 4.131
# La prediccion para Chamber, The (1996) es: 4.131
# La prediccion para Apple Dumpling Gang, The (1975) es: 4.131
# La prediccion para Davy Crockett, King of the Wild Frontier (1955) es: 4.131
# La prediccion para Escape to Witch Mountain (1975) es: 4.131
# La prediccion para Love Bug, The (1969) es: 3.000
# La prediccion para Herbie Rides Again (1974) es: 4.131
# La prediccion para Old Yeller (1957) es: 4.131
# La prediccion para Parent Trap, The (1961) es: 4.131
# La prediccion para Pollyanna (1960) es: 4.131
# La prediccion para Homeward Bound: The Incredible Journey (1993) es: 4.131
# La prediccion para Shaggy Dog, The (1959) es: 4.131
# La prediccion para Swiss Family Robinson (1960) es: 4.131
# La prediccion para That Darn Cat! (1965) es: 4.131
# La prediccion para 20,000 Leagues Under the Sea (1954) es: 4.131
# La prediccion para Cool Runnings (1993) es: 4.131
# La prediccion para Angels in the Outfield (1994) es: 4.131
# La prediccion para Cinderella (1950) es: 3.000
# La prediccion para Winnie the Pooh and the Blustery Day (1968) es: 4.131
# La prediccion para Three Caballeros, The (1945) es: 4.131
# La prediccion para Sword in the Stone, The (1963) es: 3.000
# La prediccion para Robin Hood: Prince of Thieves (1991) es: 4.131
# La prediccion para Mary Poppins (1964) es: 3.000
# La prediccion para Dumbo (1941) es: 3.000
# La prediccion para Pete's Dragon (1977) es: 3.000
# La prediccion para Bedknobs and Broomsticks (1971) es: 4.131
# La prediccion para Alice in Wonderland (1951) es: 3.000
# La prediccion para Fox and the Hound, The (1981) es: 3.000
# La prediccion para Freeway (1996) es: 4.131
# La prediccion para Sound of Music, The (1965) es: 4.131
# La prediccion para Die Hard (1988) es: 4.131
# La prediccion para Lawnmower Man, The (1992) es: 4.131
# La prediccion para Secret Agent, The (1996) es: 4.131
# La prediccion para Secrets & Lies (1996) es: 4.131
# La prediccion para That Thing You Do! (1996) es: 4.131
# La prediccion para To Gillian on Her 37th Birthday (1996) es: 4.131
# La prediccion para Beautiful Thing (1996) es: 4.131
# La prediccion para Long Kiss Goodnight, The (1996) es: 4.131
# La prediccion para Ghost and the Darkness, The (1996) es: 4.131
# La prediccion para Looking for Richard (1996) es: 4.131
# La prediccion para Trees Lounge (1996) es: 4.131
# La prediccion para Normal Life (1996) es: 4.131
# La prediccion para Get on the Bus (1996) es: 4.131
# La prediccion para Shadow Conspiracy (1997) es: 4.131
# La prediccion para Jude (1996) es: 4.131
# La prediccion para Everyone Says I Love You (1996) es: 4.131
# La prediccion para William Shakespeare's Romeo + Juliet (1996) es: 4.750
# La prediccion para Swingers (1996) es: 4.131
# La prediccion para Sleepers (1996) es: 4.131
# La prediccion para Aladdin and the King of Thieves (1996) es: 4.131
# La prediccion para Shall We Dance (1937) es: 4.131
# La lista es empty
# La prediccion para Willy Wonka & the Chocolate Factory (1971) es: 4.131
# La lista es empty
# La prediccion para Sleeper (1973) es: 4.131
# La prediccion para Bananas (1971) es: 4.131
# La prediccion para Fish Called Wanda, A (1988) es: 4.131
# La prediccion para Monty Python's Life of Brian (1979) es: 4.131
# La prediccion para Victor/Victoria (1982) es: 4.131
# La prediccion para Candidate, The (1972) es: 3.500
# La prediccion para Great Race, The (1965) es: 4.131
# La prediccion para Bonnie and Clyde (1967) es: 4.131
# La prediccion para Old Man and the Sea, The (1958) es: 4.131
# La prediccion para Dial M for Murder (1954) es: 4.131
# La prediccion para Dirty Dancing (1987) es: 4.131
# La prediccion para Platoon (1986) es: 4.131
# La prediccion para Weekend at Bernie's (1989) es: 4.131
# La prediccion para Basic Instinct (1992) es: 4.131
# La prediccion para Doors, The (1991) es: 4.131
# La prediccion para Crying Game, The (1992) es: 4.131
# La prediccion para Glengarry Glen Ross (1992) es: 4.131
# La prediccion para Sophie's Choice (1982) es: 4.131
# La prediccion para Christmas Carol, A (1938) es: 4.131
# La prediccion para Days of Thunder (1990) es: 4.131
# La prediccion para Top Gun (1986) es: 3.250
# La prediccion para Rebel Without a Cause (1955) es: 4.131
# La prediccion para Streetcar Named Desire, A (1951) es: 4.131
# La prediccion para Children of the Corn IV: The Gathering (1996) es: 4.131
# La prediccion para Loser (1991) es: 4.131
# La prediccion para Microcosmos (Microcosmos: Le peuple de l'herbe) (1996) es: 4.131
# La prediccion para Palookaville (1996) es: 4.131
# La prediccion para Funeral, The (1996) es: 4.131
# La prediccion para Single Girl, A (Fille seule, La) (1995) es: 4.131
# La prediccion para Eighth Day, The (Huitième jour, Le) (1996) es: 4.131
# La prediccion para Drunks (1995) es: 4.131
# La prediccion para People vs. Larry Flynt, The (1996) es: 4.131
# La prediccion para Glory Daze (1995) es: 4.131
# La prediccion para Perfect Candidate, A (1996) es: 4.131
# La prediccion para On Golden Pond (1981) es: 4.131
# La prediccion para Return of the Pink Panther, The (1975) es: 4.131
# La prediccion para Drop Dead Fred (1991) es: 4.131
# La prediccion para Abyss, The (1989) es: 4.131
# La prediccion para Fog, The (1980) es: 4.131
# La prediccion para Escape from New York (1981) es: 4.131
# La prediccion para Howling, The (1980) es: 4.131
# La prediccion para Jean de Florette (1986) es: 4.131
# La prediccion para Manon of the Spring (Manon des sources) (1986) es: 4.131
# La prediccion para Private Benjamin (1980) es: 4.131
# La prediccion para Monty Python and the Holy Grail (1975) es: 4.131
# La prediccion para Hustler White (1996) es: 4.131
# La prediccion para Entertaining Angels: The Dorothy Day Story (1996) es: 4.131
# La prediccion para Line King: The Al Hirschfeld Story, The (1996) es: 4.131
# La prediccion para When We Were Kings (1996) es: 4.131
# La prediccion para Wallace & Gromit: The Wrong Trousers (1993) es: 4.131
# La prediccion para Return of Martin Guerre, The (Retour de Martin Guerre, Le) (1982) es: 4.131
# La prediccion para Lesson Faust (1994) es: 4.131
# La prediccion para Children Are Watching Us, The (Bambini ci guardano, I) (1944) es: 4.131
# La prediccion para Tin Drum, The (Blechtrommel, Die) (1979) es: 4.131
# La prediccion para Ruling Class, The (1972) es: 4.131
# La prediccion para Mina Tannenbaum (1994) es: 4.131
# La prediccion para Dear God (1996) es: 4.131
# La prediccion para Best of the Best 3: No Turning Back (1995) es: 4.131
# La prediccion para Bob Roberts (1992) es: 3.500
# La prediccion para Cinema Paradiso (Nuovo cinema Paradiso) (1989) es: 4.131
# La prediccion para Cook the Thief His Wife & Her Lover, The (1989) es: 4.131
# La prediccion para Delicatessen (1991) es: 4.131
# La prediccion para Double Life of Veronique, The (Double Vie de Véronique, La) (1991) es: 4.131
# La prediccion para Enchanted April (1992) es: 4.131
# La prediccion para Paths of Glory (1957) es: 4.131
# La prediccion para Grifters, The (1990) es: 4.131
# La prediccion para Hear My Song (1991) es: 4.131
# La prediccion para English Patient, The (1996) es: 4.131
# La prediccion para Mediterraneo (1991) es: 4.131
# La prediccion para My Left Foot (1989) es: 4.131
# La prediccion para Sex, Lies, and Videotape (1989) es: 4.131
# La prediccion para Passion Fish (1992) es: 4.131
# La prediccion para Strictly Ballroom (1992) es: 4.131
# La prediccion para Thin Blue Line, The (1988) es: 4.131
# La prediccion para Tie Me Up! Tie Me Down! (¡Átame!) (1990) es: 4.131
# La prediccion para Madonna: Truth or Dare (1991) es: 4.131
# La prediccion para Paris Is Burning (1990) es: 4.131
# La prediccion para Cheech and Chong's Up in Smoke (1978) es: 4.131
# La prediccion para Princess Bride, The (1987) es: 4.131
# La prediccion para Brazil (1985) es: 4.131
# La prediccion para Aliens (1986) es: 3.500
# ...
# La prediccion para The Space Between Us (2016) es: 4.131
# La prediccion para Underworld: Blood Wars (2016) es: 4.131
# La prediccion para Miss Sloane (2016) es: 4.131
# La prediccion para Hidden Figures (2016) es: 4.131
# La prediccion para Fences (2016) es: 4.131
# La prediccion para The Founder (2016) es: 4.131
# La prediccion para Why Him? (2016) es: 4.131
# La prediccion para Sing (2016) es: 4.131
# La prediccion para I Am Not Your Negro (2017) es: 4.131
# La prediccion para Iron Man (1931) es: 4.131
# La prediccion para Assassin's Creed (2016) es: 4.131
# La prediccion para A Dog's Purpose (2017) es: 4.131
# La prediccion para Microwave Massacre (1983) es: 4.131
# La prediccion para The OA es: 4.131
# La prediccion para Fist Fight (2017) es: 4.131
# La prediccion para Shakespeare Behind Bars (2005) es: 4.131
# La prediccion para A Street Cat Named Bob (2016) es: 4.131
# La prediccion para The Lego Batman Movie (2017) es: 3.650
# La prediccion para The Spirit of Christmas (1995) es: 4.131
# La prediccion para The Good Boy (2016) es: 4.131
# La prediccion para Dana Carvey: Straight White Male, 60 (2016) es: 4.131
# La prediccion para Marvel One-Shot: Agent Carter (2013) es: 4.131
# La prediccion para Kizumonogatari II: Passionate Blood (2016) es: 4.131
# La prediccion para Joe Rogan: Live (2006) es: 4.131
# La prediccion para Jim Gaffigan: Cinco (2017) es: 4.131
# La prediccion para Kizumonogatari III: Cold Blood (2017) es: 4.131
# La prediccion para Kong: Skull Island (2017) es: 4.131
# La prediccion para T2: Trainspotting (2017) es: 4.131
# La prediccion para The Big Sick (2017) es: 4.131
# La prediccion para 100 Streets (2016) es: 4.131
# La prediccion para Saturn 3 (1980) es: 4.131
# La prediccion para Beauty and the Beast (2017) es: 4.131
# La prediccion para The Boss Baby (2017) es: 4.131
# La prediccion para Mercury Plains (2016) es: 4.131
# La prediccion para Call Me by Your Name (2017) es: 4.131
# La prediccion para Mudbound (2017) es: 4.131
# La prediccion para Ghost in the Shell (2017) es: 4.131
# La prediccion para Bill Burr: Walk Your Way Out (2017) es: 4.131
# La prediccion para Fifty Shades Darker (2017) es: 4.131
# La prediccion para Neal Brennan: 3 Mics (2017) es: 4.131
# La prediccion para Lemonade (2016) es: 4.131
# La prediccion para American Fable (2017) es: 4.131
# La prediccion para The Void (2016) es: 4.131
# La prediccion para Guyver: Dark Hero (1994) es: 4.131
# La prediccion para Denis Leary: No Cure for Cancer (1993) es: 4.131
# La prediccion para Buster's Mal Heart (2017) es: 4.131
# La prediccion para Power Rangers (2017) es: 4.131
# La prediccion para Alien: Covenant (2017) es: 4.131
# La prediccion para Free Fire (2017) es: 4.131
# La prediccion para Species III (2004) es: 4.131
# La prediccion para Ultimate Avengers 2 (2006) es: 4.131
# La prediccion para Mulholland Dr. (1999) es: 4.131
# La prediccion para Dave Chappelle: The Age of Spin (2017) es: 4.131
# La prediccion para CHiPS (2017) es: 4.131
# La prediccion para Table 19 (2017) es: 4.131
# La prediccion para Dave Chappelle: Deep in the Heart of Texas (2017) es: 4.131
# La prediccion para The Quiet Family (1998) es: 4.131
# La prediccion para A Plasticine Crow (1981) es: 4.131
# La prediccion para Gifted (2017) es: 4.131
# La prediccion para Band of Brothers (2001) es: 4.131
# La prediccion para There Once Was a Dog (1982) es: 4.131
# La prediccion para Baywatch (2017) es: 4.131
# La prediccion para Snatched (2017) es: 4.131
# La prediccion para Life-Size (2000) es: 4.131
# La prediccion para The Fate of the Furious (2017) es: 4.131
# La prediccion para Sandy Wexler (2017) es: 4.131
# La prediccion para Betting on Zero (2016) es: 4.131
# La prediccion para Win It All (2017) es: 4.131
# La prediccion para Captain Underpants: The First Epic Movie (2017) es: 4.131
# La lista es empty
# La prediccion para Cars 3 (2017) es: 4.131
# La prediccion para Mini's First Time (2006) es: 4.131
# La prediccion para Planet Earth II (2016) es: 4.131
# La prediccion para The Hero (2017) es: 4.131
# La prediccion para Nobody Speak: Hulk Hogan, Gawker and Trials of a Free Press (2017) es: 4.131
# La prediccion para Cosmos es: 4.131
# La prediccion para Maria Bamford: Old Baby es: 4.131
# La prediccion para Robin Williams: Live on Broadway (2002) es: 4.131
# La prediccion para The Death of Louis XIV (2016) es: 4.131
# La prediccion para Death Note: Desu nôto (2006–2007) es: 4.131
# La prediccion para Munna bhai M.B.B.S. (2003) es: 4.131
# La prediccion para The Beguiled (2017) es: 4.131
# La prediccion para Okja (2017) es: 4.131
# La prediccion para Embassy (2013) es: 4.131
# La prediccion para Rough Night (2017) es: 4.131
# La prediccion para Generation Iron 2 es: 4.131
# La prediccion para Mystère à la Tour Eiffel (2015) es: 4.131
# La prediccion para Stefan Zweig: Farewell to Europe (2016) es: 4.131
# La prediccion para Saved by the Bell: Hawaiian Style (1992) es: 4.131
# La prediccion para Plain Clothes (1988) es: 4.131
# La prediccion para The Prime Gig (2000) es: 4.131
# La prediccion para The Night Before (1988) es: 4.131
# La prediccion para Late Night with Conan O'Brien: The Best of Triumph the Insult Comic Dog (2004) es: 4.131
# La prediccion para Get Me Roger Stone (2017) es: 4.131
# La prediccion para T2 3-D: Battle Across Time (1996) es: 4.131
# La prediccion para Despicable Me 3 (2017) es: 4.131
# La prediccion para Last Year's Snow Was Falling (1983) es: 4.131
# La prediccion para Investigation Held by Kolobki (1986) es: 4.131
# La prediccion para Karlson Returns (1970) es: 4.131
# La prediccion para Vacations in Prostokvashino (1980) es: 4.131
# La prediccion para Winter in Prostokvashino (1984) es: 4.131
# La prediccion para Priklyucheniya Kapitana Vrungelya (1979) es: 4.131
# La prediccion para Tickling Giants (2017) es: 4.131
# La prediccion para Vovka in the Kingdom of Far Far Away (1965) es: 4.131
# La prediccion para Adventures of Mowgli: The Kidnapping (1968) es: 4.131
# La prediccion para A Detective Story (2003) es: 4.131
# La prediccion para Final Flight of the Osiris (2003) es: 4.131
# La prediccion para Kid's Story (2003) es: 4.131
# La prediccion para Cheburashka (1971) es: 4.131
# La prediccion para War for the Planet of the Apes (2017) es: 4.131
# La prediccion para The Square (2017) es: 4.131
# La prediccion para The Meyerowitz Stories (2017) es: 4.131
# La prediccion para War Machine (2017) es: 4.131
# La prediccion para Tokyo Idols (2017) es: 4.131
# La prediccion para Vir Das: Abroad Understanding (2017) es: 4.131
# La prediccion para Norm Macdonald: Hitler's Dog, Gossip & Trickery (2017) es: 4.131
# La prediccion para Valerian and the City of a Thousand Planets (2017) es: 4.131
# La prediccion para The Gracefield Incident (2015) es: 4.131
# La prediccion para Shadow World (2016) es: 4.131
# La prediccion para Wow! A Talking Fish! (1983) es: 4.131
# La prediccion para Travels of an Ant (1983) es: 4.131
# La prediccion para The Adventures of Sherlock Holmes and Doctor Watson: The Hunt for the Tiger (1980) es: 4.131
# La prediccion para Fugitives (1986) es: 4.131
# La prediccion para Tiger Raid (2016) es: 4.131
# La prediccion para Gulliver's Travels (1996) es: 4.131
# La prediccion para Atomic Blonde (2017) es: 4.131
# La prediccion para Empties (2007) es: 4.131
# La prediccion para Goon: Last of the Enforcers (2017) es: 4.131
# La prediccion para Dunkirk (2017) es: 4.131
# La prediccion para Belladonna of Sadness (1973) es: 4.131
# La prediccion para The Putin Interviews (2017) es: 4.131
# La prediccion para Unedited Footage of a Bear (2014) es: 4.131
# La prediccion para Obsession (1965) es: 4.131
# La prediccion para Oh, Hello: On Broadway (2017) es: 4.131
# La prediccion para Good Time (2017) es: 4.131
# La prediccion para Don Camillo in Moscow (1965) es: 4.131
# La prediccion para The House (2017) es: 4.131
# La prediccion para Logan Lucky (2017) es: 4.131
# La prediccion para The Dark Tower (2017) es: 4.131
# La prediccion para Annabelle: Creation (2017) es: 4.131
# La prediccion para Gena the Crocodile (1969) es: 4.131
# La prediccion para On the Trail of the Bremen Town Musicians (1973) es: 4.131
# La prediccion para In the blue sea, in the white foam. (1984) es: 4.131
# La prediccion para Wolf and Calf (1984) es: 4.131
# La prediccion para Bobik Visiting Barbos (1977) es: 4.131
# La prediccion para The Magic Ring (1982) es: 4.131
# La prediccion para The Emoji Movie (2017) es: 4.131
# La prediccion para Death Note (2017) es: 4.131
# La prediccion para Wind River (2017) es: 4.131
# La prediccion para Rory Scovel Tries Stand-Up for the First Time (2017) es: 4.131
# La prediccion para Shot Caller (2017) es: 4.131
# La prediccion para Rick and Morty: State of Georgia Vs. Denver Fenton Allen (2016) es: 4.131
# La prediccion para Themroc (1973) es: 4.131
# La prediccion para A German Life (2016) es: 4.131
# La prediccion para Self-criticism of a Bourgeois Dog (2017) es: 4.131
# La prediccion para Der Herr Karl (1961) es: 4.131
# La prediccion para LEGO DC Super Hero Girls: Brain Drain (2017) es: 4.131
# La prediccion para Kingsman: The Golden Circle (2017) es: 4.131
# La prediccion para Ari Shaffir: Double Negative (2017) es: 4.131
# La prediccion para The Nut Job 2: Nutty by Nature (2017) es: 4.131
# La prediccion para Bliss (2012) es: 4.131
# La prediccion para Alles Inklusive (2014) es: 4.131
# La prediccion para Mother! (2017) es: 4.131
# La prediccion para Icarus (2017) es: 4.131
# La prediccion para Cage Dive (2017) es: 4.131
# La prediccion para Boniface's Holiday (1965) es: 4.131
# La prediccion para American Made (2017) es: 4.131
# La prediccion para Little Boxes (2017) es: 4.131
# La prediccion para Geostorm (2017) es: 4.131
# La prediccion para Maz Jobrani: Immigrant (2017) es: 4.131
# La prediccion para Sword Art Online The Movie: Ordinal Scale (2017) es: 4.131
# La prediccion para Three Billboards Outside Ebbing, Missouri (2017) es: 4.131
# La prediccion para Lady Bird (2017) es: 4.131
# La prediccion para Murder on the Orient Express (2017) es: 4.131
# La prediccion para Coco (2017) es: 4.131
# La prediccion para The Night Is Short, Walk on Girl (2017) es: 4.131
# La prediccion para I, Tonya (2017) es: 4.131
# La prediccion para Fireworks, Should We See It from the Side or the Bottom? (2017) es: 4.131
# La prediccion para Adventures in Plymptoons! (2011) es: 4.131
# La prediccion para Gaga: Five Foot Two (2017) es: 4.131
# La prediccion para Dave Chappelle: Killin' Them Softly (2000) es: 4.131
# La prediccion para Front Cover (2016) es: 4.131
# La prediccion para Paddington 2 (2017) es: 4.131
# La prediccion para 2048: Nowhere to Run (2017) es: 4.131
# La prediccion para Male Hunt (1964) es: 4.131
# La prediccion para The Death of Stalin (2017) es: 4.131
# La prediccion para Loving Vincent (2017) es: 4.131
# La prediccion para Blue Planet II (2017) es: 4.131
# La prediccion para Christina P: Mother Inferior (2017) es: 4.131
# La prediccion para Dane Cook: Troublemaker (2014) es: 4.131
# La prediccion para Mayhem (2017) es: 4.131
# La prediccion para Emerald Green (2016) es: 4.131
# La prediccion para Wonder Wheel (2017) es: 4.131
# La prediccion para Creep 2 (2017) es: 4.131
# La prediccion para LBJ (2017) es: 4.131
# La prediccion para Roman J. Israel, Esq. (2017) es: 4.131
# La prediccion para Darkest Hour (2017) es: 4.131
# La prediccion para A Bad Moms Christmas (2017) es: 4.131
# La prediccion para The Shape of Water (2017) es: 4.500
# La prediccion para Molly's Game (2017) es: 4.131
# La prediccion para Wonder (2017) es: 4.131
# La prediccion para Daddy's Home 2 (2017) es: 4.131
# La prediccion para The Shining (1997) es: 4.131
# La prediccion para Jim & Andy: The Great Beyond (2017) es: 4.131
# La prediccion para The Disaster Artist (2017) es: 4.131
# La prediccion para The Post (2017) es: 4.131
# La prediccion para Die Frauen von Ravensbrück (2005) es: 4.131
# La prediccion para The Greatest Showman (2017) es: 4.131
# La prediccion para Ferdinand (2017) es: 4.131
# La prediccion para Jack Whitehall: At Large (2017) es: 4.131
# La prediccion para Lynne Koplitz: Hormonal Beast (2017) es: 4.131
# La prediccion para Phantom Thread (2017) es: 4.131
# La prediccion para Too Funny to Fail: The Life and Death of The Dana Carvey Show (2017) es: 4.131
# La prediccion para Craig Ferguson: Tickle Fight (2017) es: 4.131
# La prediccion para Serving in Silence: The Margarethe Cammermeyer Story (1995) es: 4.131
# La prediccion para Hare-um Scare-um (1939) es: 4.131
# La prediccion para Porky in Wackyland (1938) es: 4.131
# La prediccion para Porky's Hare Hunt (1938) es: 4.131
# La prediccion para The Second Renaissance Part II (2003) es: 4.131
# La prediccion para A Christmas Story Live! (2017) es: 4.131
# La prediccion para Pixel Perfect (2004) es: 4.131
# La prediccion para Judd Apatow: The Return (2017) es: 4.131
# La prediccion para The Purple Sea (2009) es: 4.131
# La prediccion para Bright (2017) es: 4.131
# La prediccion para The Commuter (2018) es: 4.131
# La prediccion para Dave Chappelle: Equanimity (2017) es: 4.131
# La prediccion para Quest (2017) es: 4.131
# La prediccion para Dave Chappelle: The Bird Revelation (2017) es: 4.131
# La prediccion para Insidious: The Last Key (2018) es: 4.131
# La prediccion para The Tale of the Bunny Picnic (1986) es: 4.131
# La prediccion para Patti Rocks (1988) es: 4.131
# La prediccion para Maze Runner: The Death Cure (2018) es: 4.131
# La prediccion para Isle of Dogs (2018) es: 4.131
# La prediccion para The Clapper (2018) es: 4.131
# La prediccion para Tom Segura: Disgraceful (2018) es: 4.131
# La prediccion para When We First Met (2018) es: 4.131
# La prediccion para Battle Planet (2008) es: 4.131
# La prediccion para De platte jungle (1978) es: 4.131
# La prediccion para The Cloverfield Paradox (2018) es: 4.131
# La prediccion para Making a Murderer (2015) es: 4.131
# La prediccion para Elsa & Fred (2005) es: 4.131
# La prediccion para Fullmetal Alchemist 2018 (2017) es: 4.131
# La prediccion para First Reformed (2017) es: 4.131
# La prediccion para Fred Armisen: Standup for Drummers (2018) es: 4.131
# La prediccion para Death Wish (2018) es: 4.131
# La prediccion para A Wrinkle in Time (2018) es: 4.131
# La prediccion para Love, Simon (2018) es: 4.131
# La prediccion para A Quiet Place (2018) es: 4.131
# La prediccion para I Kill Giants (2018) es: 4.131
# La prediccion para Game Over, Man! (2018) es: 4.131
# La prediccion para Blockers (2018) es: 4.131
# La prediccion para Pacific Rim: Uprising (2018) es: 4.131
# La prediccion para Rampage (2018) es: 4.131
# La prediccion para Jurassic World: Fallen Kingdom (2018) es: 4.131
# La prediccion para Incredibles 2 (2018) es: 4.131
# La prediccion para Won't You Be My Neighbor? (2018) es: 4.131
# La prediccion para Sorry to Bother You (2018) es: 4.131
# La prediccion para Ant-Man and the Wasp (2018) es: 4.131
# La prediccion para Dogman (2018) es: 4.131
# La prediccion para Mamma Mia: Here We Go Again! (2018) es: 4.131
# La prediccion para Tag (2018) es: 4.131
# La prediccion para The Man Who Killed Don Quixote (2018) es: 4.131
# La prediccion para Boundaries (2018) es: 4.131
# La prediccion para Spiral (2018) es: 4.131
# La prediccion para Mission: Impossible - Fallout (2018) es: 4.131
# La prediccion para SuperFly (2018) es: 4.131
# La prediccion para Iron Soldier (2010) es: 4.131
# La prediccion para BlacKkKlansman (2018) es: 4.131
# La prediccion para The Darkest Minds (2018) es: 4.131
# La prediccion para Tilt (2011) es: 4.131
# La prediccion para Jeff Ross Roasts the Border (2017) es: 4.131
# La prediccion para John From (2015) es: 4.131
# La prediccion para Liquid Truth (2017) es: 4.131
# La prediccion para Bunny (1998) es: 4.131
# La prediccion para Hommage à Zgougou (et salut à Sabine Mamou) (2002) es: 4.131
# La prediccion para Gintama (2017) es: 4.131
# La prediccion para Gintama: The Movie (2010) es: 3.722
# La prediccion para anohana: The Flower We Saw That Day - The Movie (2013) es: 4.131
# La prediccion para Silver Spoon (2014) es: 4.131
# La prediccion para Love Live! The School Idol Movie (2015) es: 4.131
# La prediccion para Jon Stewart Has Left the Building (2015) es: 4.131
# La prediccion para Black Butler: Book of the Atlantic (2017) es: 4.131
# La prediccion para No Game No Life: Zero (2017) es: 4.131
# La prediccion para Flint (2017) es: 4.131
# La prediccion para Bungo Stray Dogs: Dead Apple (2018) es: 4.131
# La prediccion para Andrew Dice Clay: Dice Rules (1991) es: 4.131

# %%
df = df.sort_values(by='ratingPredict', ascending = False)

# %%
df.head(100)
# Out:
#       movieId                                             title ratingPredict
# 1670     2247                         Married to the Mob (1988)         5.000
# 914      1213                                 Goodfellas (1990)         5.000
# 6468    52712                             Invisible, The (2007)         5.000
# 6593    55290                             Gone Baby Gone (2007)         5.000
# 1124     1466                              Donnie Brasco (1997)         5.000
# ...       ...                                               ...           ...
# 6436    51698                            Last Mimzy, The (2007)         4.131
# 6435    51694                             Starter for 10 (2006)         4.131
# 6467    52694                         Mr. Bean's Holiday (2007)         4.131
# 6434    51666                             Abandoned, The (2006)         4.131
# 6362    49666  Fur: An Imaginary Portrait of Diane Arbus (2006)         4.131
#
# [100 rows x 3 columns]
