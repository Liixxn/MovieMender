# %%
import requests
import pandas as pd
from concurrent.futures import ThreadPoolExecutor
from bs4 import BeautifulSoup
import time
import threading

# %%
import concurrent.futures

# %%
df_links = pd.read_csv('csv/links.csv')

# %%
df_movies = pd.read_csv('csv/movies.csv')

# %%
df_ratings = pd.read_csv('csv/ratings.csv')

# %%
df_tags = pd.read_csv('csv/tags.csv')

# %%
header = {
    'User-Agent': 'Chrome 108.0.5359.125',
    'Accept-Language': 'es'
}

# %%
df_links.isnull().sum()
# Out:
# movieId    0
# imdbId     0
# tmdbId     8
# dtype: int64

# %%
df_links = df_links.dropna()

# %%
df_links.isnull().sum()
# Out:
# movieId    0
# imdbId     0
# tmdbId     0
# dtype: int64

# %%
columnaSinopsis=[]
with ThreadPoolExecutor(max_workers=100) as p:
    try:
        for idPeli in df_links['tmdbId']:
            print(str(idPeli))
            url = "https://www.themoviedb.org/movie/"+str(int(idPeli))
            page = requests.get(url,headers=header)
            soup = BeautifulSoup (page.content, 'html.parser')
            sinopsis = soup.find(class_="overview")
            sinopsis = sinopsis.text
            sinopsis = str(sinopsis)
            #print(sinopsis)
            columnaSinopsis.append(sinopsis)
    except:
        columnaSinopsis.append("SinInformacion")
# Out:
# 862.0
# 8844.0
# 15602.0
# 31357.0
# 11862.0
# 949.0
# 11860.0
# 45325.0
# 9091.0

# %%
df_links
# Out:
#       movieId   imdbId    tmdbId
# 0           1   114709     862.0
# 1           2   113497    8844.0
# 2           3   113228   15602.0
# 3           4   114885   31357.0
# 4           5   113041   11862.0
# ...       ...      ...       ...
# 9737   193581  5476944  432131.0
# 9738   193583  5914996  445030.0
# 9739   193585  6397426  479308.0
# 9740   193587  8391976  483455.0
# 9741   193609   101726   37891.0
#
# [9734 rows x 3 columns]

# %%
df_links1 = df_links.loc[0:1081]
df_links2 = df_links.loc[1082:2163]
df_links3 = df_links.loc[2164:3244]
df_links4 = df_links.loc[3245:4325]
df_links5 = df_links.loc[4326:5406]
df_links6 = df_links.loc[5407:6487]
df_links7 = df_links.loc[6488:7568]
df_links8 = df_links.loc[7569:8649]
df_links9 = df_links.loc[8650:9734]

# %%
columnaSinopsis1=[]
columnaSinopsis2=[]
columnaSinopsis3=[]
columnaSinopsis4=[]
columnaSinopsis5=[]
columnaSinopsis6=[]
columnaSinopsis7=[]
columnaSinopsis8=[]
columnaSinopsis9=[]

# %%
columnaSinopsis=[]
for idPeli in df_links['tmdbId']:
    print(int(idPeli))
        url = "https://www.themoviedb.org/movie/"+str(int(idPeli))
        page = requests.get(url,headers=header)
        soup = BeautifulSoup (page.content, 'html.parser')
        sinopsis = soup.find(class_="overview")
        sinopsis = sinopsis.text
        sinopsis = str(sinopsis)
        #print(sinopsis)
        columnaSinopsis.append(sinopsis)
columnaSinopsis
# Out:
#   Input In [11]
#     except exception e:
#                      ^
# SyntaxError: invalid syntax

# %%
def scrapping(thread_name):
    
    if thread_name == "thread1":
        for idPeli in df_links1['tmdbId']:
            try:
                print(str(idPeli))
                url = "https://www.themoviedb.org/movie/"+str(int(idPeli))
                page = requests.get(url,headers=header)
                soup = BeautifulSoup (page.content, 'html.parser')
                sinopsis = soup.find(class_="overview")
                sinopsis = sinopsis.text
                sinopsis = str(sinopsis)
                #print(sinopsis)
                columnaSinopsis1.append(sinopsis)
            except:
                columnaSinopsis1.append("SinInformacion")

    if thread_name == "thread2":
        for idPeli in df_links2['tmdbId']:
            try:
                print(str(idPeli))
                url = "https://www.themoviedb.org/movie/"+str(int(idPeli))
                page = requests.get(url,headers=header)
                soup = BeautifulSoup (page.content, 'html.parser')
                sinopsis = soup.find(class_="overview")
                sinopsis = sinopsis.text
                sinopsis = str(sinopsis)
                #print(sinopsis)
                columnaSinopsis2.append(sinopsis)
            except:
                columnaSinopsis2.append("SinInformacion")

    if thread_name == "thread3":

        for idPeli in df_links3['tmdbId']:
            try:
                print(str(idPeli))
                url = "https://www.themoviedb.org/movie/"+str(int(idPeli))
                page = requests.get(url,headers=header)
                soup = BeautifulSoup (page.content, 'html.parser')
                sinopsis = soup.find(class_="overview")
                sinopsis = sinopsis.text
                sinopsis = str(sinopsis)
                #print(sinopsis)
                columnaSinopsis3.append(sinopsis)
            except:
                columnaSinopsis3.append("SinInformacion")
                
                
    if thread_name == "thread4":
        for idPeli in df_links4['tmdbId']:
            try:
                print(str(idPeli))
                url = "https://www.themoviedb.org/movie/"+str(int(idPeli))
                page = requests.get(url,headers=header)
                soup = BeautifulSoup (page.content, 'html.parser')
                sinopsis = soup.find(class_="overview")
                sinopsis = sinopsis.text
                sinopsis = str(sinopsis)
                #print(sinopsis)
                columnaSinopsis4.append(sinopsis)
            except:
                columnaSinopsis4.append("SinInformacion")
    
    
    if thread_name == "thread5":
        for idPeli in df_links5['tmdbId']:
            try:
                print(str(idPeli))
                url = "https://www.themoviedb.org/movie/"+str(int(idPeli))
                page = requests.get(url,headers=header)
                soup = BeautifulSoup (page.content, 'html.parser')
                sinopsis = soup.find(class_="overview")
                sinopsis = sinopsis.text
                sinopsis = str(sinopsis)
                #print(sinopsis)
                columnaSinopsis5.append(sinopsis)
            except:
                columnaSinopsis5.append("SinInformacion")
                
                
    if thread_name == "thread6":
        for idPeli in df_links6['tmdbId']:
            try:
                print(str(idPeli))
                url = "https://www.themoviedb.org/movie/"+str(int(idPeli))
                page = requests.get(url,headers=header)
                soup = BeautifulSoup (page.content, 'html.parser')
                sinopsis = soup.find(class_="overview")
                sinopsis = sinopsis.text
                sinopsis = str(sinopsis)
                #print(sinopsis)
                columnaSinopsis6.append(sinopsis)
            except:
                columnaSinopsis6.append("SinInformacion")
                
                
    if thread_name == "thread7":
        for idPeli in df_links7['tmdbId']:
            try:
                print(str(idPeli))
                url = "https://www.themoviedb.org/movie/"+str(int(idPeli))
                page = requests.get(url,headers=header)
                soup = BeautifulSoup (page.content, 'html.parser')
                sinopsis = soup.find(class_="overview")
                sinopsis = sinopsis.text
                sinopsis = str(sinopsis)
                #print(sinopsis)
                columnaSinopsis7.append(sinopsis)
            except:
                columnaSinopsis7.append("SinInformacion")
                
                
    if thread_name == "thread8":
        for idPeli in df_links8['tmdbId']:
            try:
                print(str(idPeli))
                url = "https://www.themoviedb.org/movie/"+str(int(idPeli))
                page = requests.get(url,headers=header)
                soup = BeautifulSoup (page.content, 'html.parser')
                sinopsis = soup.find(class_="overview")
                sinopsis = sinopsis.text
                sinopsis = str(sinopsis)
                #print(sinopsis)
                columnaSinopsis8.append(sinopsis)
            except:
                columnaSinopsis8.append("SinInformacion")
                
                
    if thread_name == "thread9":
        for idPeli in df_links9['tmdbId']:
            try:
                print(str(idPeli))
                url = "https://www.themoviedb.org/movie/"+str(int(idPeli))
                page = requests.get(url,headers=header)
                soup = BeautifulSoup (page.content, 'html.parser')
                sinopsis = soup.find(class_="overview")
                sinopsis = sinopsis.text
                sinopsis = str(sinopsis)
                #print(sinopsis)
                columnaSinopsis9.append(sinopsis)
            except:
                columnaSinopsis9.append("SinInformacion")
    
    
    
 

    
thread1 = threading.Thread(target=scrapping, args=("thread1",))
  
thread2 = threading.Thread(target=scrapping, args=("thread2",))
  
thread3 = threading.Thread(target=scrapping, args=("thread3",))

thread4 = threading.Thread(target=scrapping, args=("thread4",))

thread5 = threading.Thread(target=scrapping, args=("thread5",))

thread6 = threading.Thread(target=scrapping, args=("thread6",))

thread7 = threading.Thread(target=scrapping, args=("thread7",))

thread8 = threading.Thread(target=scrapping, args=("thread8",))

thread9 = threading.Thread(target=scrapping, args=("thread9",))
    
thread1.start()
thread2.start()
thread3.start()
thread4.start()
thread5.start()
thread6.start()
thread7.start()
thread8.start()
thread9.start()


thread1.join()
thread2.join()
thread3.join()
thread4.join()
thread5.join()
thread6.join()
thread7.join()
thread8.join()
thread9.join()
# Out:
# 862.0
# 1802.0
# 10974.0
# 2140.0
# 10743.0
# 626.0
# 285.0
# 49018.0
# 260346.0
# 4248.0
# 8844.0
# 49010.0
# 4232.0
# 12526.0
# 27899.0
# 10398.0
# 201088.0
# 2832.0
# 17612.0
# 15602.0
# 3432.0
# 9361.0
# 55725.0
# 2290.0
# 48365.0
# 126644.0
# 31459.0
# 3134.0
# 14208.0
# 24071.0
# 31357.0
# 38868.0
# 294652.0
# 2928.0
# 48650.0
# 877.0
# 8217.0
# 62994.0
# 14207.0
# 11862.0
# 39356.0
# 87101.0
# 39130.0
# 10549.0
# 60994.0
# 15098.0
# 22478.0
# 24200.0
# 949.0
# 60307.0
# 58102.0
# 31511.0
# 5488.0
# 86705.0
# 26483.0
# 16112.0
# 11458.0
# 11860.0
# 18451.0
# 43904.0
# 32305.0
# 10063.0
# 53172.0
# 45325.0
# 27317.0
# 24382.0
# 16636.0
# 27265.0
# 12225.0
# 14615.0
# 14429.0
# 18736.0
# 68352.0
# 9091.0
# 50359.0
# 11286.0
# 49935.0
# 31773.0
# 298.0
# 710.0
# 15198.0
# 64484.0
# 11950.0
# 267573.0
# 36658.0
# 8818.0
# 24807.0
# 9087.0
# 75725.0
# 6415.0
# 36758.0
# 10832.0
# 36245.0
# 46989.0
# 14749.0
# 12110.0
# 43874.0
# 24066.0
# 26573.0
# 36040.0
# 58857.0
# 289394.0
# ...

# %%
13894.028377.0

# %%
# De 0:04:30 aprox a 0:20:00 con 3 hilos

# %%
columnaSinopsis1
